# %% [markdown]
# # BMTF input stubs fit with 3 group of stubs

# %% [markdown]
# ## Imports and setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import mplhep as hep

import os
import warnings

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import layers, optimizers, losses, callbacks, regularizers

# %%
hep.style.use("CMS")

warnings.filterwarnings("ignore")

mpl.rcParams["figure.dpi"] = 70

# %%
print(f"Training device: {'GPU' if tf.config.list_physical_devices('GPU') else 'CPU'}")
# Out:
# Training device: GPU

# %% [markdown]
# ## Constants

# %%
USER = os.getenv("USER")

# FILE_PATH = "/eos/cms/store/cmst3/group/daql1scout/ml_data/run3/bmtf_stubs_refit/"
FILE_PATH = "/mnt/ml_data/run3/bmtf_stubs_refit/"

FILE_SAVE_DATA = "/mnt/ml_data/run3/bmtf_stubs_refit_dummy/Data3NN/"

FILE_NAME = "rereco"

OUT_PATH = "."
LOSS_FNAME = "losses.csv"

FIGSIZE = (12, 7)

petroff_10 = ["#3f90da", "#ffa90e", "#bd1f01", "#94a4a2", "#832db6", "#a96b59", "#e76300", "#b9ac70", "#717581", "#92dadd"]
plt.rcParams["axes.prop_cycle"] = plt.cycler('color', petroff_10)

# %% [markdown]
# ## Classes

# %% [markdown]
# ### Neural Network model for regression+classification task

# %%
class MultiTaskNN(tf.keras.Model):
    def __init__(self, architecture, reg_strength=0.01):
        super(MultiTaskNN, self).__init__()

        # Check if the architecture list has at least 2 values (input size and one hidden layer)
        if len(architecture) < 2:
            raise ValueError("Architecture must contain at least input size and one hidden layer.")

        self.layers_list = []

        # Iterate over the architecture list to dynamically create dense layers followed by batch normalization
        for i in range(1, len(architecture)):
            self.layers_list.append(layers.Dense(architecture[i], kernel_regularizer=regularizers.l2(reg_strength)))
            self.layers_list.append(layers.Activation('elu'))

        self.regression_head = layers.Dense(3, kernel_regularizer=regularizers.l2(reg_strength))  # for pt, eta, phi

    def call(self, inputs):
        x = inputs
        for layer in self.layers_list:
            x = layer(x)

        reg_output = self.regression_head(x)
        return reg_output

# %% [markdown]
# ### Custom Learning Rate scheduler

# %%
# Custom learning rate scheduler callback
class CustomLRScheduler(tf.keras.callbacks.Callback):
    def __init__(
        self, 
        optimizer, 
        factor=0.5, 
        patience=5, 
        min_improvement=0.01, 
        verbose=True
    ):
        super(CustomLRScheduler, self).__init__()
        self.optimizer = optimizer
        self.factor = factor
        self.patience = patience
        self.min_improvement = min_improvement
        self.verbose = verbose
        self.best_loss = float('inf')
        self.patience_counter = 0

        
        
    def on_epoch_begin(self, epoch, logs=None):
        if epoch == 0:
            self.optimizer.lr.assign(self.min_lr)
        if epoch < self.decrease_epoch:
            self.increase_flag = True
        else:
            self.increase_flag = False


    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        loss = logs.get("val_loss")

        if loss:
            relative_improvement = (self.best_loss - loss) / self.best_loss

            if relative_improvement < self.min_improvement:
                self.patience_counter += 1
            else:
                self.patience_counter = 0
                self.best_loss = loss

            if self.patience_counter >= self.patience:
                self._decrease_lr()

    def _decrease_lr(self):
        old_lr = self.optimizer.lr.numpy()
        new_lr = old_lr * self.factor
        self.optimizer.lr.assign(new_lr)
        if self.verbose:
            print(f"Decreasing learning rate to {new_lr}")

# %% [markdown]
# # Read Data

# %%
#create datasets data_3
data_3 = pd.read_csv(FILE_SAVE_DATA + 'data_3s.csv')

# %%
data_3
# Out:
#         n_stubs  ptRecoInverse  etaExtRecoSt2  phiExtRecoSt2  chargeReco  \
# 0           3.0       0.133071      -0.509130      -0.965212         1.0
# 1           3.0       0.171997       0.798967      -2.217150         1.0
# 2           3.0       0.152530      -0.805635      -0.027324         1.0
# 3           3.0       0.173533       0.778853      -0.910298         0.0
# 4           3.0       0.166120       0.610290      -3.077410         0.0
# ...         ...            ...            ...            ...         ...
# 992444      3.0       0.043140      -0.325648      -1.413110         1.0
# 992445      3.0       0.044758       0.015691      -2.639930         1.0
# 992446      3.0       0.098257       0.286685      -2.613320         0.0
# 992447      3.0       0.032039      -0.717806       2.411800         0.0
# 992448      3.0       0.032645       0.302539      -0.111966         1.0
#
#         ptL1     etaL1     phiL1  hwSignL1  a_stNum  ...  c_qeta_1  c_eta_2  \
# 0        6.5 -0.500250 -1.003560       0.0      1.0  ...       2.0    255.0
# 1        7.0  0.793875 -2.258020       0.0      1.0  ...       1.0    255.0
# 2        7.0 -0.793875 -0.043633       0.0      1.0  ...       2.0    255.0
# 3        7.0  0.739500 -0.905390       1.0      1.0  ...       1.0    255.0
# 4        6.5  0.598125 -3.087050       1.0      1.0  ...       0.0      7.0
# ...      ...       ...       ...       ...      ...  ...       ...      ...
# 992444  32.0 -0.315375 -1.418080       0.0      2.0  ...       0.0      7.0
# 992445  19.5  0.000000 -2.650720       0.0      1.0  ...       0.0      7.0
# 992446  11.0  0.348000 -2.596180       1.0      2.0  ...       0.0      7.0
# 992447  69.5 -0.761250  2.399830       1.0      2.0  ...       0.0      7.0
# 992448  41.0  0.315375 -0.119991       0.0      2.0  ...       0.0      7.0
#
#         c_qeta_2  c_tag   c_phi  c_phiB  c_quality  info_a  info_b  info_c
# 0            0.0    1.0   136.0   -17.0        3.0     1.0     2.0     3.0
# 1            0.0    1.0  -729.0   -29.0        5.0     1.0     2.0     3.0
# 2            0.0    1.0  -211.0    -5.0        6.0     1.0     2.0     3.0
# 3            0.0    1.0   686.0    44.0        6.0     1.0     2.0     3.0
# 4            0.0    1.0   338.0   -42.0        6.0     1.0     2.0     4.0
# ...          ...    ...     ...     ...        ...     ...     ...     ...
# 992444       0.0    1.0   617.0    -4.0        6.0     2.0     3.0     4.0
# 992445       0.0    1.0  -116.0    10.0        6.0     1.0     3.0     4.0
# 992446       0.0    1.0   188.0     3.0        3.0     2.0     3.0     4.0
# 992447       0.0    1.0  1316.0     9.0        5.0     2.0     3.0     4.0
# 992448       0.0    1.0  -477.0   -19.0        2.0     2.0     3.0     4.0
#
# [992449 rows x 45 columns]

# %% [markdown]
# ## Normalizations setup

# %%
n_stubs_norm         = 2**2
station_norm         = 2**2
sector_norm          = 2**3
wheel_norm           = 2**1
eta_norm             = 2**8
qeta_norm            = 2**1
tag_norm             = 2**0
phi_norm             = 2**11
phib_norm            = 2**9
quality_norm         = 2**3
reco_pt_norm         = 2**0
reco_pt_inverse_norm = 2**0
reco_eta_norm        = 2**2
reco_phi_norm        = 2**2
reco_charge_norm     = 2**0
info_norm          = 2**2

normalizations = {
    "n_stubs": n_stubs_norm,
    "info_a": info_norm,
    "info_b": info_norm,
    "info_c": info_norm,
    "info_d": info_norm,
    "a_stNum": station_norm,
    "a_scNum": sector_norm,
    "a_whNum": wheel_norm,
    "a_eta_1": eta_norm,
    "a_qeta_1": qeta_norm,
    "a_eta_2": eta_norm,
    "a_qeta_2": qeta_norm,
    "a_tag": tag_norm,
    "a_phi": phi_norm,
    "a_phiB": phib_norm,
    "a_quality": quality_norm,
    "b_stNum": station_norm,
    "b_scNum": sector_norm,
    "b_whNum": wheel_norm,
    "b_eta_1": eta_norm,
    "b_qeta_1": qeta_norm,
    "b_eta_2": eta_norm,
    "b_qeta_2": qeta_norm,
    "b_tag": tag_norm,
    "b_phi": phi_norm,
    "b_phiB": phib_norm,
    "b_quality": quality_norm,
    "c_stNum": station_norm,
    "c_scNum": sector_norm,
    "c_whNum": wheel_norm,
    "c_eta_1": eta_norm,
    "c_qeta_1": qeta_norm,
    "c_eta_2": eta_norm,
    "c_qeta_2": qeta_norm,
    "c_tag": tag_norm,
    "c_phi": phi_norm,
    "c_phiB": phib_norm,
    "c_quality": quality_norm,
    "d_stNum": station_norm,
    "d_scNum": sector_norm,
    "d_whNum": wheel_norm,
    "d_eta_1": eta_norm,
    "d_qeta_1": qeta_norm,
    "d_eta_2": eta_norm,
    "d_qeta_2": qeta_norm,
    "d_tag": tag_norm,
    "d_phi": phi_norm,
    "d_phiB": phib_norm,
    "d_quality": quality_norm,
    # "ptReco": reco_pt_norm,
    "ptRecoInverse": reco_pt_inverse_norm,
    "etaExtRecoSt2": reco_eta_norm,
    "phiExtRecoSt2": reco_phi_norm,
    "chargeReco": reco_charge_norm,
}

# %%
data_3.keys()
# Out:
# Index(['n_stubs', 'ptRecoInverse', 'etaExtRecoSt2', 'phiExtRecoSt2',
#        'chargeReco', 'ptL1', 'etaL1', 'phiL1', 'hwSignL1', 'a_stNum',
#        'a_scNum', 'a_whNum', 'a_eta_1', 'a_qeta_1', 'a_eta_2', 'a_qeta_2',
#        'a_tag', 'a_phi', 'a_phiB', 'a_quality', 'b_stNum', 'b_scNum',
#        'b_whNum', 'b_eta_1', 'b_qeta_1', 'b_eta_2', 'b_qeta_2', 'b_tag',
#        'b_phi', 'b_phiB', 'b_quality', 'c_stNum', 'c_scNum', 'c_whNum',
#        'c_eta_1', 'c_qeta_1', 'c_eta_2', 'c_qeta_2', 'c_tag', 'c_phi',
#        'c_phiB', 'c_quality', 'info_a', 'info_b', 'info_c'],
#       dtype='object')

# %%
stub_features_2 = [
    'n_stubs', 
    'info_a', 'info_b',
    'a_stNum', 'a_scNum', 'a_whNum', 'a_eta_1', 'a_qeta_1', 'a_eta_2', 'a_qeta_2', 'a_tag', 'a_phi', 'a_phiB', 'a_quality',
    'b_stNum', 'b_scNum', 'b_whNum', 'b_eta_1', 'b_qeta_1', 'b_eta_2', 'b_qeta_2', 'b_tag', 'b_phi', 'b_phiB', 'b_quality'
]

stub_features_3 = [
    'n_stubs', 
    'info_a', 'info_b', 'info_c',
    'a_stNum', 'a_scNum', 'a_whNum', 'a_eta_1', 'a_qeta_1', 'a_eta_2', 'a_qeta_2', 'a_tag', 'a_phi', 'a_phiB', 'a_quality',
    'b_stNum', 'b_scNum', 'b_whNum', 'b_eta_1', 'b_qeta_1', 'b_eta_2', 'b_qeta_2', 'b_tag', 'b_phi', 'b_phiB', 'b_quality',
    'c_stNum', 'c_scNum', 'c_whNum', 'c_eta_1', 'c_qeta_1', 'c_eta_2', 'c_qeta_2', 'c_tag', 'c_phi', 'c_phiB', 'c_quality'
]

stub_features_4 = [
    'n_stubs', 
    'info_a', 'info_b', 'info_c', 'info_d',
    'a_stNum', 'a_scNum', 'a_whNum', 'a_eta_1', 'a_qeta_1', 'a_eta_2', 'a_qeta_2', 'a_tag', 'a_phi', 'a_phiB', 'a_quality',
    'b_stNum', 'b_scNum', 'b_whNum', 'b_eta_1', 'b_qeta_1', 'b_eta_2', 'b_qeta_2', 'b_tag', 'b_phi', 'b_phiB', 'b_quality',
    'c_stNum', 'c_scNum', 'c_whNum', 'c_eta_1', 'c_qeta_1', 'c_eta_2', 'c_qeta_2', 'c_tag', 'c_phi', 'c_phiB', 'c_quality',
    'd_stNum', 'd_scNum', 'd_whNum', 'd_eta_1', 'd_qeta_1', 'd_eta_2', 'd_qeta_2', 'd_tag', 'd_phi', 'd_phiB', 'd_quality'
]

target_features = [
    'ptRecoInverse', 'etaExtRecoSt2', 'phiExtRecoSt2',
]

l1_features = [
    'ptL1', 'etaL1', 'phiL1', 'hwSignL1',
]

# %% [markdown]
# # NN with 3 stubs
#
# data_3 are the data that we are gonna use.

# %%
train_val_data, test_data = train_test_split(data_3,      test_size=0.3, random_state=42)
train_data, val_data      = train_test_split(train_val_data, test_size=0.1, random_state=42)

# %%
# inspect the datasets
print(f"Train dataset: {len(train_data)}")
print(f"Val dataset: {len(val_data)}")
print(f"Test dataset: {len(test_data)}")
# Out:
# Train dataset: 625242
# Val dataset: 69472
# Test dataset: 297735

# %% [markdown]
# ## Normalization process
#
# First we need to use the keys() of the normalization dictionary that are present for the data_2, since we have just 2 features.

# %%
#function that create a new dictionary with the features of nromalizations that are present in the data_2
def get_normalizations_features(data, normalizations):
    return {key: normalizations[key] for key in data.keys() if key in normalizations}

get_normalizations_features(data_3, normalizations)
# Out:
# {'n_stubs': 4,
#  'ptRecoInverse': 1,
#  'etaExtRecoSt2': 4,
#  'phiExtRecoSt2': 4,
#  'chargeReco': 1,
#  'a_stNum': 4,
#  'a_scNum': 8,
#  'a_whNum': 2,
#  'a_eta_1': 256,
#  'a_qeta_1': 2,
#  'a_eta_2': 256,
#  'a_qeta_2': 2,
#  'a_tag': 1,
#  'a_phi': 2048,
#  'a_phiB': 512,
#  'a_quality': 8,
#  'b_stNum': 4,
#  'b_scNum': 8,
#  'b_whNum': 2,
#  'b_eta_1': 256,
#  'b_qeta_1': 2,
#  'b_eta_2': 256,
#  'b_qeta_2': 2,
#  'b_tag': 1,
#  'b_phi': 2048,
#  'b_phiB': 512,
#  'b_quality': 8,
#  'c_stNum': 4,
#  'c_scNum': 8,
#  'c_whNum': 2,
#  'c_eta_1': 256,
#  'c_qeta_1': 2,
#  'c_eta_2': 256,
#  'c_qeta_2': 2,
#  'c_tag': 1,
#  'c_phi': 2048,
#  'c_phiB': 512,
#  'c_quality': 8,
#  'info_a': 4,
#  'info_b': 4,
#  'info_c': 4}

# %%
# normalize the data
for key in get_normalizations_features(data_3, normalizations):
    train_data[key] = train_data[key] / normalizations[key]
    val_data[key]   = val_data[key]   / normalizations[key]
    test_data[key]  = test_data[key]  / normalizations[key]

# %%
train_data
# Out:
#         n_stubs  ptRecoInverse  etaExtRecoSt2  phiExtRecoSt2  chargeReco  \
# 68447      0.75       0.193130      -0.088023       0.703715         0.0
# 137943     0.75       0.108564      -0.168545      -0.398630         0.0
# 853000     0.75       0.197956       0.093640      -0.030681         1.0
# 627364     0.75       0.149320      -0.168798       0.031116         1.0
# 581977     0.75       0.034895       0.131420      -0.358517         1.0
# ...         ...            ...            ...            ...         ...
# 836891     0.75       0.158437      -0.053505       0.657018         1.0
# 600455     0.75       0.056021      -0.080689       0.690580         0.0
# 567009     0.75       0.046594       0.148103      -0.515185         1.0
# 938610     0.75       0.075348       0.036156       0.621598         1.0
# 582273     0.75       0.017074       0.033586      -0.274112         0.0
#
#         ptL1     etaL1     phiL1  hwSignL1  a_stNum  ...  c_qeta_1   c_eta_2  \
# 68447    6.5 -0.369750  2.781620       1.0     0.25  ...       0.0  0.027344
# 137943  14.5 -0.641625 -1.625340       1.0     0.50  ...       0.0  0.027344
# 853000   6.0  0.369750 -0.152716       0.0     0.25  ...       0.0  0.027344
# 627364   9.0 -0.685125  0.098175       0.0     0.25  ...       0.0  0.027344
# 581977  34.5  0.522000 -1.439900       0.0     0.25  ...       1.0  0.996094
# ...      ...       ...       ...       ...      ...  ...       ...       ...
# 836891   8.0 -0.206625  2.628900       0.0     0.25  ...       0.0  0.027344
# 600455  18.5 -0.315375  2.759800       1.0     0.50  ...       0.0  0.027344
# 567009  23.0  0.576375 -2.061670       0.0     0.25  ...       0.0  0.027344
# 938610  20.5  0.141375  2.498000       0.0     0.50  ...       0.0  0.027344
# 582273  62.5  0.130500 -1.101740       1.0     0.25  ...       0.0  0.027344
#
#         c_qeta_2  c_tag     c_phi    c_phiB  c_quality  info_a  info_b  info_c
# 68447        0.0    1.0  0.408203  0.076172      0.750    0.25    0.50    0.75
# 137943       0.0    1.0 -0.046387  0.044922      0.750    0.50    0.75    1.00
# 853000       0.0    1.0 -0.339355 -0.039062      0.625    0.25    0.50    0.75
# 627364       0.0    1.0  0.176758  0.025391      0.750    0.25    0.75    1.00
# 581977       0.0    1.0  0.263184 -0.023438      0.750    0.25    0.50    0.75
# ...          ...    ...       ...       ...        ...     ...     ...     ...
# 836891       0.0    1.0 -0.033691  0.001953      0.750    0.25    0.50    1.00
# 600455       0.0    1.0  0.330078  0.005859      0.625    0.50    0.75    1.00
# 567009       0.0    1.0  0.051270  0.025391      0.375    0.25    0.50    1.00
# 938610       0.0    1.0 -0.260742 -0.017578      0.750    0.50    0.75    1.00
# 582273       0.0    1.0 -0.090332  0.007812      0.625    0.25    0.50    1.00
#
# [625242 rows x 45 columns]

# %% [markdown]
# ## NN Model

# %%
# Hyperparameters
input_size    = len(stub_features_3)
architecture  = [input_size, 16, 16, 16, 8]
output_size   = len(target_features)
learning_rate = 1e-2
num_epochs    = 300
batch_size    = 2**8
reg_strength  = 1e-3

# lr scheduler
scale_factor = 0.5
patience = 5
min_loss_improvement = 0.1

# Early stopping variables
best_val_loss = float('inf')
epochs_without_improvement = 0
patience = 10  # Number of epochs to wait before stopping
early_stopping_threshold = 1e-5  # Minimum improvement in loss function to be considered as improvement

# Loss and optimizer
# regression_criterion     = losses.MeanSquaredError()
regression_criterion     = losses.MeanAbsoluteError()


optimizer = optimizers.Adam(learning_rate=learning_rate)
scheduler = CustomLRScheduler(
    optimizer, 
    factor=scale_factor, 
    patience=patience, 
    min_improvement=min_loss_improvement, 
    verbose=True
)
# Out:
# 2024-07-23 14:02:29.121350: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10518 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:04:00.0, compute capability: 6.1
# 2024-07-23 14:02:29.121896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 10532 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:82:00.0, compute capability: 6.1

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_data[stub_features_3].values, train_data[target_features].values)).batch(batch_size).shuffle(buffer_size=len(train_data))
val_dataset   = tf.data.Dataset.from_tensor_slices((val_data[stub_features_3].values, val_data[target_features].values)).batch(batch_size)
test_dataset  = tf.data.Dataset.from_tensor_slices((test_data[stub_features_3].values, test_data[target_features].values)).batch(batch_size)

# %%
# Create the model
model_3 = MultiTaskNN(architecture, reg_strength=reg_strength)

# Build the model with the batch input shape
bs = None  # None allows for variable batch size
model_3.build((bs, input_size))

# Print the number of parameters
total_params = model_3.count_params()
trainable_vars = [var for var in model_3.trainable_variables]
trainable_params = sum([tf.size(var).numpy() for var in trainable_vars])
print(f"Total number of parameters: {total_params}")
print(f"Number of trainable parameters: {trainable_params}")
# Out:
# Total number of parameters: 1315
# Number of trainable parameters: 1315

# %%
@tf.function
def train_step(features, targets):
    with tf.GradientTape() as tape:
        regression_targets = targets[:, :]
        reg_outputs = model_3(features, training=True)
        regression_loss = regression_criterion(regression_targets, reg_outputs)
        loss = regression_loss

    gradients = tape.gradient(loss, model_3.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model_3.trainable_variables))

    return regression_loss, loss

@tf.function
def val_step(features, targets):
    regression_targets = targets[:, :]
    reg_outputs = model_3(features, training=False)
    regression_loss = regression_criterion(regression_targets, reg_outputs)
    loss = regression_loss 
    return regression_loss, loss

# %% [markdown]
# ## Train model

# %%
train_regression_losses     = []
val_regression_losses       = []

learning_rates = []

out_file = open(os.path.join(OUT_PATH, LOSS_FNAME), "w")
out_file.write("train_regression_loss,val_regression_loss,learning_rate\n")


# Training loop
for epoch in range(num_epochs):
    # Training
    running_loss                = 0.0
    running_regression_loss     = 0.0
    
    # scheduler.on_epoch_begin(epoch, logs=None)
    
    for features, targets in train_dataset:
        
        regression_loss, loss = train_step(features, targets)
        
        running_loss                += loss.numpy()
        running_regression_loss     += regression_loss.numpy()
        

        
    # Note: Remember to adjust if not using batches of equal sizes
    train_loss                = running_loss                / len(train_dataset)
    train_regression_loss     = running_regression_loss     / len(train_dataset)

    train_regression_losses.append(train_regression_loss)

    # Validation
    running_loss                = 0.0
    running_regression_loss     = 0.0
    
    for features, targets in val_dataset:
        
        regression_loss, loss = val_step(features, targets)
        
        running_loss                += loss.numpy()
        running_regression_loss     += regression_loss.numpy()
    
    avg_val_loss                = running_loss                / len(val_dataset)
    avg_val_regression_loss     = running_regression_loss     / len(val_dataset)
        
    val_regression_losses.append(avg_val_regression_loss)
    
    
    current_lr = optimizer.lr.numpy()
    learning_rates.append(current_lr)
    
    
    
    print(f"Epoch [{epoch + 1}/{num_epochs}]")
    print(f"Learning rate: {current_lr:.2e}")
    print(f"Train Losses - Regression: {train_regression_losses[-1]:.5f}")
    print(f"Validation Losses - Regression: {val_regression_losses[-1]:.5f}")
    print("-------------")
    
    
    scheduler.on_epoch_end(epoch, {"val_loss": avg_val_loss})


    with open(os.path.join(OUT_PATH, LOSS_FNAME), "a") as output_file:
        output_file.write(f"{train_regression_losses[-1]},{val_regression_losses[-1]},{current_lr}\n")

    # Check for early stopping based on the new criterion
    if avg_val_loss < (1 - early_stopping_threshold) * best_val_loss:  # 0.001 corresponds to 0.1%
        epochs_without_improvement = 0
        best_val_loss = min(best_val_loss, avg_val_loss)
    else:
        epochs_without_improvement += 1

    if epochs_without_improvement >= patience:
        print(f"Early stopping triggered after {epoch + 1} epochs!")
        break
# Out:
# 2024-07-23 14:03:37.589726: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fc538b2e410 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-23 14:03:37.589760: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2024-07-23 14:03:37.589787: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2024-07-23 14:03:37.596478: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-23 14:03:37.619233: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721736217.695768 3083261 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch [1/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.04442
# Validation Losses - Regression: 0.02100
# -------------
# Epoch [2/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01850
# Validation Losses - Regression: 0.01626
# -------------
# Epoch [3/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01624
# Validation Losses - Regression: 0.01483
# -------------
# Epoch [4/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01471
# Validation Losses - Regression: 0.01453
# -------------
# Epoch [5/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01364
# Validation Losses - Regression: 0.01199
# -------------
# Epoch [6/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01332
# Validation Losses - Regression: 0.01224
# -------------
# Epoch [7/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01291
# Validation Losses - Regression: 0.01396
# -------------
# Epoch [8/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01274
# Validation Losses - Regression: 0.01211
# -------------
# Epoch [9/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01261
# Validation Losses - Regression: 0.01372
# -------------
# Epoch [10/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01249
# Validation Losses - Regression: 0.01107
# -------------
# Epoch [11/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01237
# Validation Losses - Regression: 0.01363
# -------------
# Epoch [12/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01234
# Validation Losses - Regression: 0.01297
# -------------
# Epoch [13/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01223
# Validation Losses - Regression: 0.01208
# -------------
# Epoch [14/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01208
# Validation Losses - Regression: 0.01214
# -------------
# Epoch [15/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.01213
# Validation Losses - Regression: 0.01202
# -------------
# Decreasing learning rate to 0.004999999888241291
# Epoch [16/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.01060
# Validation Losses - Regression: 0.01020
# -------------
# Epoch [17/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.01067
# Validation Losses - Regression: 0.01121
# -------------
# Epoch [18/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.01060
# Validation Losses - Regression: 0.01081
# -------------
# Epoch [19/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.01060
# Validation Losses - Regression: 0.01100
# -------------
# Epoch [20/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.01056
# Validation Losses - Regression: 0.01020
# -------------
# Epoch [21/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.01055
# Validation Losses - Regression: 0.01098
# -------------
# Epoch [22/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.01058
# Validation Losses - Regression: 0.01038
# -------------
# Epoch [23/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.01056
# Validation Losses - Regression: 0.01030
# -------------
# Epoch [24/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.01053
# Validation Losses - Regression: 0.01009
# -------------
# Epoch [25/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.01052
# Validation Losses - Regression: 0.01078
# -------------
# Epoch [26/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.01055
# Validation Losses - Regression: 0.01046
# -------------
# Decreasing learning rate to 0.0024999999441206455
# Epoch [27/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.00994
# Validation Losses - Regression: 0.01002
# -------------
# Decreasing learning rate to 0.0012499999720603228
# Epoch [28/300]
# Learning rate: 1.25e-03
# Train Losses - Regression: 0.00971
# Validation Losses - Regression: 0.00972
# -------------
# Decreasing learning rate to 0.0006249999860301614
# Epoch [29/300]
# Learning rate: 6.25e-04
# Train Losses - Regression: 0.00958
# Validation Losses - Regression: 0.00967
# -------------
# Decreasing learning rate to 0.0003124999930150807
# Epoch [30/300]
# Learning rate: 3.12e-04
# Train Losses - Regression: 0.00952
# Validation Losses - Regression: 0.00949
# -------------
# Decreasing learning rate to 0.00015624999650754035
# Epoch [31/300]
# Learning rate: 1.56e-04
# Train Losses - Regression: 0.00948
# Validation Losses - Regression: 0.00942
# -------------
# Decreasing learning rate to 7.812499825377017e-05
# Epoch [32/300]
# Learning rate: 7.81e-05
# Train Losses - Regression: 0.00946
# Validation Losses - Regression: 0.00941
# -------------
# Decreasing learning rate to 3.9062499126885086e-05
# Epoch [33/300]
# Learning rate: 3.91e-05
# Train Losses - Regression: 0.00944
# Validation Losses - Regression: 0.00940
# -------------
# Decreasing learning rate to 1.9531249563442543e-05
# Epoch [34/300]
# Learning rate: 1.95e-05
# Train Losses - Regression: 0.00944
# Validation Losses - Regression: 0.00940
# -------------
# Decreasing learning rate to 9.765624781721272e-06
# Epoch [35/300]
# Learning rate: 9.77e-06
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 4.882812390860636e-06
# Epoch [36/300]
# Learning rate: 4.88e-06
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 2.441406195430318e-06
# Epoch [37/300]
# Learning rate: 2.44e-06
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 1.220703097715159e-06
# Epoch [38/300]
# Learning rate: 1.22e-06
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 6.103515488575795e-07
# Epoch [39/300]
# Learning rate: 6.10e-07
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 3.0517577442878974e-07
# Epoch [40/300]
# Learning rate: 3.05e-07
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 1.5258788721439487e-07
# Epoch [41/300]
# Learning rate: 1.53e-07
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 7.629394360719743e-08
# Epoch [42/300]
# Learning rate: 7.63e-08
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 3.814697180359872e-08
# Epoch [43/300]
# Learning rate: 3.81e-08
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 1.907348590179936e-08
# Epoch [44/300]
# Learning rate: 1.91e-08
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 9.53674295089968e-09
# Epoch [45/300]
# Learning rate: 9.54e-09
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 4.76837147544984e-09
# Epoch [46/300]
# Learning rate: 4.77e-09
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 2.38418573772492e-09
# Epoch [47/300]
# Learning rate: 2.38e-09
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 1.19209286886246e-09
# Epoch [48/300]
# Learning rate: 1.19e-09
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 5.9604643443123e-10
# Epoch [49/300]
# Learning rate: 5.96e-10
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 2.98023217215615e-10
# Epoch [50/300]
# Learning rate: 2.98e-10
# Train Losses - Regression: 0.00943
# Validation Losses - Regression: 0.00939
# -------------
# Decreasing learning rate to 1.490116086078075e-10
# Early stopping triggered after 50 epochs!

# %% [markdown]
# ### Predict the test data from `test_data`

# %%
test_features = test_data[stub_features_3].values
test_targets  = test_data[target_features].values

reg_predictions = model_3(test_features, training=False)

# %%
print(test_targets[:50, 2] - reg_predictions[:50,2])
# Out:
# tf.Tensor(
# [-5.99831343e-04 -1.24147534e-03  3.85235250e-03  4.14341688e-04
#  -3.75159085e-04  1.49150193e-02  5.26542962e-03  1.37457252e-03
#   3.51500511e-03 -2.04658508e-03  2.21443176e-03  1.34021044e-03
#   1.65203884e-01  1.33013725e-03  1.61126256e-04 -1.45503879e-03
#   5.88434935e-03  3.55154276e-04  6.33895397e-04  3.49342823e-04
#  -3.88151407e-03 -1.25063956e-02  2.34842300e-05 -5.74111938e-04
#  -3.04776430e-03 -9.66995955e-03  1.41955912e-02  1.18315220e-03
#  -5.90986013e-03  1.06394291e-03 -3.49980593e-03  1.14256144e-03
#  -1.18002295e-03  1.48586929e-03  5.30481339e-06 -4.98563051e-04
#   3.30525637e-03 -1.02829933e-03 -5.82188368e-04 -7.83526897e-03
#  -2.89767981e-04  1.31130219e-04  6.58631325e-04  2.74008512e-03
#   1.37512535e-02 -4.07636166e-04  3.36170197e-04  2.48022377e-04
#   7.88360834e-03 -1.44541264e-03], shape=(50,), dtype=float32)

# %%
test_features = test_data[stub_features_3].values
test_targets  = test_data[target_features].values

reg_predictions = model_3(test_features, training=False)


test_df = pd.DataFrame(
    np.concatenate(
        (
            test_features,
            test_targets,
            reg_predictions.numpy(),
            test_data[l1_features].values,
        ),
        axis=1
    ),
    columns=stub_features_3 + target_features + ["ptRecoInverse_pred", "etaExtRecoSt2_pred", "phiExtRecoSt2_pred"] + l1_features
)


# rescale the features
for key in get_normalizations_features(test_df, normalizations):
    test_df[key] = test_df[key] * normalizations[key]
    
# rescale the predictions
test_df["ptRecoInverse_pred"] = test_df["ptRecoInverse_pred"] * normalizations["ptRecoInverse"]
test_df["etaExtRecoSt2_pred"] = test_df["etaExtRecoSt2_pred"] * normalizations["etaExtRecoSt2"]
test_df["phiExtRecoSt2_pred"] = test_df["phiExtRecoSt2_pred"] * normalizations["phiExtRecoSt2"]

# drop features keep only predictions and targets and L1 features
# test_df = test_df[["ptRecoInverse", "etaExtRecoSt2", "phiExtRecoSt2", "chargeReco", "ptRecoInverse_pred", "etaExtRecoSt2_pred", "phiExtRecoSt2_pred", "chargeReco_pred"] + l1_features]

#new line because of 'chargeReco'
print(test_df.keys())
test_df = test_df[["ptRecoInverse", "etaExtRecoSt2", "phiExtRecoSt2", "ptRecoInverse_pred", "etaExtRecoSt2_pred", "phiExtRecoSt2_pred"] + l1_features]

# create ptReco_true and etaReco_true and phiReco_true and chargeReco_true
# create ptReco_pred and etaReco_pred and phiReco_pred and chargeReco_pred
test_df["ptReco_true"]     = test_df["ptRecoInverse"].apply(lambda x: 1 / x)
test_df["etaReco_true"]    = test_df["etaExtRecoSt2"]
test_df["phiReco_true"]    = test_df["phiExtRecoSt2"]
# test_df["chargeReco_true"] = test_df["chargeReco"]

test_df["ptReco_pred"]     = test_df["ptRecoInverse_pred"].apply(lambda x: 1 / x)
test_df["etaReco_pred"]    = test_df["etaExtRecoSt2_pred"]
test_df["phiReco_pred"]    = test_df["phiExtRecoSt2_pred"]
# test_df["chargeReco_pred"] = test_df["chargeReco_pred"]

# transform hwSignL1 into chargeL1
test_df["chargeL1"] = test_df["hwSignL1"].apply(lambda x: 1 if x == 0 else 0)

# drop ptRecoInverse and etaExtRecoSt2 and phiExtRecoSt2 and chargeReco
# drop ptRecoInverse_pred and etaExtRecoSt2_pred and phiExtRecoSt2_pred and chargeReco_pred
test_df = test_df[["ptReco_true", "etaReco_true", "phiReco_true", "ptReco_pred", "etaReco_pred", "phiReco_pred", "ptL1", "etaL1", "phiL1", "chargeL1"]]


test_df
# Out:
# Index(['n_stubs', 'info_a', 'info_b', 'info_c', 'a_stNum', 'a_scNum',
#        'a_whNum', 'a_eta_1', 'a_qeta_1', 'a_eta_2', 'a_qeta_2', 'a_tag',
#        'a_phi', 'a_phiB', 'a_quality', 'b_stNum', 'b_scNum', 'b_whNum',
#        'b_eta_1', 'b_qeta_1', 'b_eta_2', 'b_qeta_2', 'b_tag', 'b_phi',
#        'b_phiB', 'b_quality', 'c_stNum', 'c_scNum', 'c_whNum', 'c_eta_1',
#        'c_qeta_1', 'c_eta_2', 'c_qeta_2', 'c_tag', 'c_phi', 'c_phiB',
#        'c_quality', 'ptRecoInverse', 'etaExtRecoSt2', 'phiExtRecoSt2',
#        'ptRecoInverse_pred', 'etaExtRecoSt2_pred', 'phiExtRecoSt2_pred',
#        'ptL1', 'etaL1', 'phiL1', 'hwSignL1'],
#       dtype='object')
#         ptReco_true  etaReco_true  phiReco_true  ptReco_pred  etaReco_pred  \
# 0          28.54160     -0.030101      1.021050    24.086328     -0.010616
# 1          11.43140     -0.230860      1.596880    10.993081     -0.227375
# 2          10.11110      0.176333      0.654713    10.622740      0.169600
# 3          20.90200      0.223922     -1.046040    20.326032      0.228961
# 4          17.45740     -0.342543     -0.161378    17.786255     -0.361354
# ...             ...           ...           ...          ...           ...
# 297730     41.34400      0.318139     -1.431560    32.358058      0.314601
# 297731      5.03936     -0.443425      0.551990     4.998393     -0.494780
# 297732     22.13330     -0.709575     -1.119140    21.865726     -0.716243
# 297733     17.04800     -0.812357     -1.478240    24.095549     -0.736953
# 297734     24.51650      0.821004     -1.046610    20.261127      0.814175
#
#         phiReco_pred  ptL1     etaL1     phiL1  chargeL1
# 0           1.023449  32.5  0.000000  1.014470         1
# 1           1.601846  14.0 -0.228375  1.603520         0
# 2           0.639304  12.5  0.163125  0.643590         0
# 3          -1.047697  29.0  0.228375 -1.058110         0
# 4          -0.159877  23.5 -0.358875 -0.163625         0
# ...              ...   ...       ...       ...       ...
# 297730     -1.426412  43.5  0.315375 -1.439900         1
# 297731      0.548998   7.0 -0.456750  0.534507         1
# 297732     -1.116581  24.0 -0.696000 -1.123560         0
# 297733     -1.468613  20.0 -0.750375 -1.483530         1
# 297734     -1.053847  31.0  0.804750 -1.058110         0
#
# [297735 rows x 10 columns]

# %%
# accuracy = (test_df["chargeReco_pred"] == test_df["chargeReco_true"]).sum() / len(test_df)

# print(f"Classification Accuracy on Test Set: {accuracy*100:.2f}%")

# l1_accuracy = (test_df["chargeL1"] == test_df["chargeReco_true"]).sum() / len(test_df)

# print(f"L1 Classification Accuracy on Test Set: {l1_accuracy*100:.2f}%")
# Out:
# Classification Accuracy on Test Set: 97.08%
# L1 Classification Accuracy on Test Set: 97.29%

# %%
prob      = True
PLOT_PATH = f"/eos/user/{USER[0]}/{USER}/nnreco-plots/"
PLOT_FLAG = False

if not os.path.exists(PLOT_PATH):
    os.makedirs(PLOT_PATH)

# %% [markdown]
# ### Resolution plots

# %%
target_features
# Out:
# ['ptRecoInverse', 'etaExtRecoSt2', 'phiExtRecoSt2']

# %%
#plot the ptReco_true and ptReco_pred
fig, ax = plt.subplots(figsize=FIGSIZE, dpi=100)
plt.hist(test_df["ptReco_true"], bins=100,  histtype="step", lw=2, label="True")
plt.hist(test_df["ptReco_pred"], bins=100,  histtype="step", lw=2, label="Predicted")
plt.xlabel("pT [GeV]")
plt.ylabel("Events")
plt.legend()
plt.title("pT Reco")
plt.grid()
plt.tight_layout()
plt.show()

#plot the etaReco_true and etaReco_pred
fig, ax = plt.subplots(figsize=FIGSIZE, dpi=100)
plt.hist(test_df["etaReco_true"], bins=100,  histtype="step", lw=2, label="True")
plt.hist(test_df["etaReco_pred"], bins=100,  histtype="step", lw=2, label="Predicted")
plt.xlabel("eta")
plt.ylabel("Events")
plt.legend()
plt.title("eta Reco")
plt.grid()
plt.tight_layout()
plt.show()

#plot the phiReco_true and phiReco_pred
fig, ax = plt.subplots(figsize=FIGSIZE, dpi=100)
plt.hist(test_df["phiReco_true"], bins=100,histtype="step", lw=2, label="True")
plt.hist(test_df["phiReco_pred"], bins=100, histtype="step", lw=2, label="Predicted")
plt.xlabel("phi")
plt.ylabel("Events")
plt.legend()
plt.title("phi Reco")
plt.grid()
plt.tight_layout()
plt.show()

# %%
eta_res_pred = (test_df.etaReco_pred - test_df.etaReco_true) / test_df.etaReco_true

# if eta_res_pred < -0.5 then add 1 to shift the histogram to the right
# mask = np.where(eta_res_pred < -0.5, 1, 0)
# eta_res_pred = eta_res_pred + mask

# recompute the predicted eta
# test_df["etaReco_pred"] = test_df.etaReco_true * (1 + eta_res_pred)

pt_res_pred = (test_df.ptReco_pred - test_df.ptReco_true) / test_df.ptReco_true
pt_res_l1   = (test_df.ptL1  - test_df.ptReco_true) / test_df.ptReco_true
pt_res_rec_l1   = (test_df.ptL1/1.2  - test_df.ptReco_true) / test_df.ptReco_true

eta_res_pred = (test_df.etaReco_pred - test_df.etaReco_true) 
eta_res_l1   = (test_df.etaL1   - test_df.etaReco_true)

phi_res_pred = (test_df.phiReco_pred - test_df.phiReco_true)
phi_res_l1   = (test_df.phiL1   - test_df.phiReco_true)


rlabel = "ZeroBias+MuonEG 2023 (13.6 TeV)"

xmin = -1.4
xmax = 1.4
binw = 0.02

fig, ax = plt.subplots(1,1, figsize=(12,9), dpi = 100)
hep.cms.label("Preliminary", loc=2, data=True, year=2024, rlabel=rlabel)
plt.hist(pt_res_l1,     bins=np.arange(xmin,xmax+binw,binw), histtype="step", lw=2, density=True, label="L1")
plt.hist(pt_res_rec_l1, bins=np.arange(xmin,xmax+binw,binw), histtype="step", lw=2, density=True, label="L1 (recal)")
plt.hist(pt_res_pred,   bins=np.arange(xmin,xmax+binw,binw), histtype="step", lw=2, density=True, label="NN reconstruction")
ax.axvline(0, color="black", linestyle="--", linewidth=3, zorder=0, alpha=0.3)
plt.xlabel("$\Delta p_T / p_T$")
plt.ylabel(f"Events (%) / {binw}")
plt.xlim(xmin, xmax)
plt.legend()
fig.savefig(f"{PLOT_PATH}/pt_res_{learning_rate}_{batch_size}_{reg_strength}_{min_loss_improvement}_{early_stopping_threshold}.pdf", dpi=300, facecolor="white")
plt.show()


xmin = -0.19
xmax = 0.19
binw = 0.0025

fig, ax = plt.subplots(1,1, figsize=(12,9), dpi = 100)
hep.cms.label("Preliminary", loc=2, data=True, year=2024, rlabel=rlabel)
plt.hist(eta_res_l1,     bins=np.arange(xmin,xmax+binw,binw), histtype="step", lw=2, density=True, label="L1")
plt.hist(eta_res_pred,   bins=np.arange(xmin,xmax+binw,binw), histtype="step", lw=2, density=True, label="NN reconstruction")
ax.axvline(0, color="black", linestyle="--", linewidth=3, zorder=0, alpha=0.3)
plt.xlabel("$\Delta \eta$")
plt.ylabel(f"Events (%) / {binw}")
plt.xlim(xmin, xmax)
plt.legend()
fig.savefig(f"{PLOT_PATH}/eta_res_{learning_rate}_{batch_size}_{reg_strength}_{min_loss_improvement}_{early_stopping_threshold}.pdf", dpi=300, facecolor="white")
plt.show()


xmin = -0.19
xmax = 0.19
binw = 0.0025

fig, ax = plt.subplots(1,1, figsize=(12,9), dpi = 100)
hep.cms.label("Preliminary", loc=2, data=True, year=2024, rlabel=rlabel)
plt.hist(phi_res_l1,     bins=np.arange(xmin,xmax+binw,binw), histtype="step", lw=2, density=True, label="L1")
plt.hist(phi_res_pred,   bins=np.arange(xmin,xmax+binw,binw), histtype="step", lw=2, density=True, label="NN reconstruction")
ax.axvline(0, color="black", linestyle="--", linewidth=3, zorder=0, alpha=0.3)
plt.xlabel("$\Delta\\varphi$ (rad)")
plt.ylabel(f"Events (%) / {binw}")
plt.xlim(xmin, xmax)
plt.legend()
fig.savefig(f"{PLOT_PATH}/phi_res_{learning_rate}_{batch_size}_{reg_strength}_{min_loss_improvement}_{early_stopping_threshold}.pdf", dpi=300, facecolor="white")
plt.show()

# %% [markdown]
# ### pT resolution vs pT perd true 2D histogram

# %%
heights.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 heights.shape
#
# NameError: name 'heights' is not defined

# %%
xmin = 0
xmax = 50
xbinw = 0.5
ymin = -1.5
ymax = 1.5
ybinw = 0.02

pt_res_pred = (test_df.ptReco_pred - test_df.ptReco_true) / test_df.ptReco_true
heights, binsx, binsy = np.histogram2d(test_df.ptReco_true, pt_res_pred, bins=(np.arange(xmin, xmax+xbinw, xbinw), np.arange(ymin, ymax+ybinw, ybinw)))

fig, ax = plt.subplots(figsize=(12,9), constrained_layout=True)
hep.cms.label(label="Preliminary", data=True, year=2023, rlabel=rlabel)

hep.hist2dplot(heights, binsx, binsy, ax=ax, cmap="viridis", flow=None, norm = mpl.colors.LogNorm())
cbar = ax.collections[0].colorbar
cbar.set_label("Events", labelpad=15) # , fontsize=36)
# cbar.ax.tick_params(labelsize=36)
# Adding labels and title
plt.xlabel("Reco muon $p_T$ (GeV)")
plt.ylabel("$\Delta p_T / p_T$")
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
if PLOT_FLAG:
    fig.savefig(f"{PLOT_PATH}pt_res_vs_pt_reco_true_zoom{learning_rate}_{batch_size}_{reg_strength}_{regression_weight}_{min_loss_improvement}_{early_stopping_threshold}.pdf", dpi=300, facecolor="white")
plt.show()

# %%
xmin = 0
xmax = 50
binw = 0.5

# Compute pT resolution
pt_res_pred = (test_df.ptReco_pred - test_df.ptReco_true) / test_df.ptReco_true
pt_res_l1   = (test_df.ptL1 / 1.2  - test_df.ptReco_true) / test_df.ptReco_true

# Define bins for pT reco true
pt_true_bins = np.arange(xmin, xmax+binw, binw)  # From 0 to 50 GeV with bin width 1 GeV

# Initialize arrays to store average pT resolution and standard deviation in each bin
avg_pt_res_pred = np.zeros(len(pt_true_bins) - 1)
std_pt_res_pred = np.zeros(len(pt_true_bins) - 1)
avg_pt_res_l1   = np.zeros(len(pt_true_bins) - 1)
std_pt_res_l1   = np.zeros(len(pt_true_bins) - 1)


# Loop through the bins to calculate average pT resolution and standard deviation
for i in range(len(pt_true_bins) - 1):
    lower_bound = pt_true_bins[i]
    upper_bound = pt_true_bins[i + 1]
    
    # Mask data points that fall within the current bin
    mask = (test_df.ptReco_true >= lower_bound) & (test_df.ptReco_true < upper_bound)
    
    # Compute the average pT resolution for the current bin
    avg_pt_res_pred[i] = np.mean(pt_res_pred[mask])
    avg_pt_res_l1[i]   = np.mean(pt_res_l1[mask])
    
    # Compute the standard deviation for the current bin
    std_pt_res_pred[i] = np.std(pt_res_pred[mask]) # / np.sqrt(len(pt_res_pred[mask]))
    std_pt_res_l1[i]   = np.std(pt_res_l1[mask])   # / np.sqrt(len(pt_res_l1[mask]))


# Create the profile plot
fig, ax = plt.subplots(figsize=(12,9), constrained_layout=True)
hep.cms.label(ax=ax, data=True, year=2023, label="Preliminary", rlabel=rlabel)
plt.plot(pt_true_bins[:-1], avg_pt_res_l1, "-", label="L1", color="C0")
plt.fill_between(pt_true_bins[:-1], avg_pt_res_l1 - std_pt_res_l1, avg_pt_res_l1 + std_pt_res_l1, alpha=0.3, color="C0")

plt.plot(pt_true_bins[:-1], avg_pt_res_pred, "-", label="NN", color="C1")
plt.fill_between(pt_true_bins[:-1], avg_pt_res_pred - std_pt_res_pred, avg_pt_res_pred + std_pt_res_pred, alpha=0.3, color="C1")

ax.axhline(0, color="black", linestyle="--", linewidth=2, zorder=0)

# Plotting the average pT resolution with error bars

# ax.errorbar(
#     x=pt_true_bins[:-1], 
#     y=avg_pt_res_l1, 
#     yerr=std_pt_res_l1, 
#     marker='o', 
#     linestyle="",
#     markersize=12,
#     elinewidth=3,
#     capthick=3,
#     capsize=5,
#     label="L1",
#     color=PALETTE[-1],
# )


# ax.errorbar(
#     x=pt_true_bins[:-1], 
#     y=avg_pt_res_pred, 
#     yerr=std_pt_res_pred, 
#     marker='o', 
#     linestyle="",
#     markersize=12,
#     elinewidth=3,
#     capthick=3,
#     capsize=5,
#     label="NN Prediction",
#     color=PALETTE[0],
# )


# ax.legend(fontsize=36, loc="upper right")


# Adding labels and title
plt.xlabel("Reco muon $p_T$ [GeV]")
plt.ylabel("$\Delta p_T / p_T$")

# ax.tick_params(axis='both', which='major', labelsize=36)

if PLOT_FLAG:
    fig.savefig(f"{PLOT_PATH}pt_res_vs_pt_reco_true_profile{learning_rate}_{batch_size}_{reg_strength}_{regression_weight}_{min_loss_improvement}_{early_stopping_threshold}.pdf", dpi=300, facecolor="white")

plt.xlim(5,xmax)
plt.ylim(-2,2)
plt.legend()
plt.show()

# %%
# plot losses
fig, ax = plt.subplots(figsize=FIGSIZE)

hep.cms.label(
    ax     = ax,
    data   = True,
    label  = "Preliminary",
    rlabel = "ZeroBias 2023C (13.6 TeV)",
    fontsize = 36,
)

ax.plot(train_regression_losses, label="Train")
ax.plot(val_regression_losses, label="Validation")
ax.set_xlabel("Epoch", fontsize=36)
ax.set_ylabel("Regression Loss", fontsize=36)
ax.legend(fontsize=36)
ax.set_yscale("log")

ax.tick_params(axis='both', which='major', labelsize=36)



fig, ax = plt.subplots(figsize=FIGSIZE)
ax.grid(which="major", axis="both", alpha=0.3, color="gray", linestyle="-")
ax.set_axisbelow(True)

hep.cms.label(
    ax     = ax,
    data   = True,
    label  = "Preliminary",
    rlabel = "ZeroBias 2023C (13.6 TeV)",
    fontsize = 36,
)

ax.plot(learning_rates, lw=3)
ax.set_xlabel("Epoch", fontsize=36)
ax.set_ylabel("Learning Rate", fontsize=36)

ax.tick_params(axis='both', which='major', labelsize=36)

if PLOT_FLAG:
    fig.savefig(f"{PLOT_PATH}learning_rate{learning_rate}_{batch_size}_{reg_strength}_{min_loss_improvement}_{early_stopping_threshold}.pdf", dpi=300, facecolor="white")

plt.show()

fig, ax = plt.subplots(figsize=FIGSIZE)
ax.grid(which="major", axis="both", alpha=0.3, color="gray", linestyle="-")
ax.set_axisbelow(True)

hep.cms.label(
    ax     = ax,
    data   = True,
    label  = "Preliminary",
    rlabel = "ZeroBias 2023C (13.6 TeV)",
    fontsize = 36,
)

ax.plot(learning_rates, lw=3)
ax.set_xlabel("Epoch", fontsize=36)
ax.set_ylabel("Learning Rate", fontsize=36)

ax.set_yscale("log")

ax.tick_params(axis='both', which='major', labelsize=36)

if PLOT_FLAG:
    fig.savefig(f"{PLOT_PATH}log_learning_rate{learning_rate}_{batch_size}_{reg_strength}_{min_loss_improvement}_{early_stopping_threshold}.pdf", dpi=300, facecolor="white")

plt.show()

# %% [markdown]
# ## Perform multiple trainings to compute average loss (TAKES A LOT OF TIME)

# %%
N_ITER = 50

# %%
@tf.function
def train_step(features, targets):
    with tf.GradientTape() as tape:
        regression_targets = targets[:, :-1]
        classification_targets = targets[:, -1]
        reg_outputs, class_outputs = model(features, training=True)
        regression_loss = regression_criterion(regression_targets, reg_outputs)
        classification_loss = classification_criterion(classification_targets, class_outputs)
        loss = regression_weight * regression_loss + classification_weight * classification_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return regression_loss, classification_loss, loss

@tf.function
def val_step(features, targets):
    regression_targets = targets[:, :-1]
    classification_targets = targets[:, -1]
    reg_outputs, class_outputs = model(features, training=False)
    regression_loss = regression_criterion(regression_targets, reg_outputs)
    classification_loss = classification_criterion(classification_targets, class_outputs)
    loss = regression_weight * regression_loss + classification_weight * classification_loss
    return regression_loss, classification_loss, loss

# %%
full_data_ = pd.DataFrame()

for file in os.listdir(FILE_PATH):
    if file.endswith(".csv"):
        full_data_ = pd.concat([full_data_, pd.read_csv(FILE_PATH + file)], ignore_index=True)
        
full_data_ = full_data_.iloc[:, :-1]

# drop rows with ptL1 == 4.5
full_data_ = full_data_[full_data_["ptL1"] != 4.5]

# drop rows with reco eta > 1 and < -1
full_data_ = full_data_[full_data_["etaExtRecoSt2"] < 1]
full_data_ = full_data_[full_data_["etaExtRecoSt2"] > -1]

# drop rows with ptL1 > 50
full_data_ = full_data_[full_data_["ptL1"] < 50]

# drop rows with ptReco > 50
full_data_ = full_data_[full_data_["ptReco"] < 50]


# mask_1 = (full_data_.etaL1 == 0) & (np.abs(full_data_.etaExtRecoSt2) == 0)
# mask_2 = (full_data_.etaL1 != 0)

# mask = mask_1 | mask_2

# full_data_ = full_data_[mask]

full_data_["ptRecoInverse"] = 1 / full_data_["ptReco"]

full_data = full_data_[stub_features + target_features + l1_features]

full_data["chargeReco"] = full_data["chargeReco"].apply(lambda x: 0 if x == -1 else 1)

# %%
classification_criterion = losses.BinaryCrossentropy(from_logits=True)
regression_criterion     = losses.MeanAbsoluteError()

# lr scheduler
scale_factor = 0.5
patience = 5
min_loss_improvement = 0.1

classification_weight = 1
regression_weight     = 5

# %%
train_regression_losses_all     = []
train_classification_losses_all = []
train_combined_losses_all       = []
val_regression_losses_all       = []
val_classification_losses_all   = []
val_combined_losses_all         = []

for i in range(N_ITER):
    
    # Hyperparameters
    input_size    = len(stub_features)
    architecture  = [input_size, 64, 32, 16, 8]
    output_size   = len(target_features)
    learning_rate = 1e-2
    num_epochs    = 300
    batch_size    = 2**10
    reg_strength  = 1e-3

    
    # Early stopping variables
    best_val_loss = float('inf')
    epochs_without_improvement = 0
    patience = 10  # Number of epochs to wait before stopping
    early_stopping_threshold = 1e-5  # Minimum improvement in loss function to be considered as improvement


    train_val_data, test_data = train_test_split(full_data,      test_size=0.3, random_state=42)
    train_data, val_data      = train_test_split(train_val_data, test_size=0.1, random_state=42)

    # normalize the data
    for key in normalizations.keys():
        train_data[key] = train_data[key] / normalizations[key]
        val_data[key]   = val_data[key]   / normalizations[key]
        test_data[key]  = test_data[key]  / normalizations[key]
        
    
    train_dataset = tf.data.Dataset.from_tensor_slices((train_data[stub_features].values, train_data[target_features].values)).batch(batch_size).shuffle(buffer_size=len(train_data))
    val_dataset   = tf.data.Dataset.from_tensor_slices((val_data[stub_features].values, val_data[target_features].values)).batch(batch_size)
    test_dataset  = tf.data.Dataset.from_tensor_slices((test_data[stub_features].values, test_data[target_features].values)).batch(batch_size)


    # Create the model
    model = MultiTaskNN(architecture, reg_strength=reg_strength)

    # Build the model with the batch input shape
    bs = None  # None allows for variable batch size
    model.build((bs, input_size))

    optimizer = optimizers.Adam(learning_rate=learning_rate)
    scheduler = CustomLRScheduler(
        optimizer, 
        factor=scale_factor, 
        patience=patience, 
        min_improvement=min_loss_improvement, 
        verbose=True
    )


    train_regression_losses     = []
    train_classification_losses = []
    train_combined_losses       = []
    val_regression_losses       = []
    val_classification_losses   = []
    val_combined_losses         = []

    learning_rates = []
    
    @tf.function
    def train_step(features, targets):
        with tf.GradientTape() as tape:
            regression_targets = targets[:, :-1]
            classification_targets = targets[:, -1]
            reg_outputs, class_outputs = model(features, training=True)
            regression_loss = regression_criterion(regression_targets, reg_outputs)
            classification_loss = classification_criterion(classification_targets, class_outputs)
            loss = regression_weight * regression_loss + classification_weight * classification_loss

        gradients = tape.gradient(loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))

        return regression_loss, classification_loss, loss

    @tf.function
    def val_step(features, targets):
        regression_targets = targets[:, :-1]
        classification_targets = targets[:, -1]
        reg_outputs, class_outputs = model(features, training=False)
        regression_loss = regression_criterion(regression_targets, reg_outputs)
        classification_loss = classification_criterion(classification_targets, class_outputs)
        loss = regression_weight * regression_loss + classification_weight * classification_loss
        return regression_loss, classification_loss, loss


    # Training loop
    for epoch in range(num_epochs):
        # Training
        running_loss                = 0.0
        running_regression_loss     = 0.0
        running_classification_loss = 0.0
        
        
        for features, targets in train_dataset:
            
            regression_loss, classification_loss, loss = train_step(features, targets)
            
            running_loss                += loss.numpy()
            running_regression_loss     += regression_loss.numpy()
            running_classification_loss += classification_loss.numpy()


            
        # Note: Remember to adjust if not using batches of equal sizes
        train_loss                = running_loss                / len(train_dataset)
        train_regression_loss     = running_regression_loss     / len(train_dataset)
        train_classification_loss = running_classification_loss / len(train_dataset)

        train_regression_losses.append(train_regression_loss)
        train_classification_losses.append(train_classification_loss)
        train_combined_losses.append(train_loss)

        # Validation
        running_loss                = 0.0
        running_regression_loss     = 0.0
        running_classification_loss = 0.0
        
        for features, targets in val_dataset:
            
            regression_loss, classification_loss, loss = val_step(features, targets)
            
            running_loss                += loss.numpy()
            running_regression_loss     += regression_loss.numpy()
            running_classification_loss += classification_loss.numpy()
        
        avg_val_loss                = running_loss                / len(val_dataset)
        avg_val_regression_loss     = running_regression_loss     / len(val_dataset)
        avg_val_classification_loss = running_classification_loss / len(val_dataset)
            
        val_regression_losses.append(avg_val_regression_loss)
        val_classification_losses.append(avg_val_classification_loss)
        val_combined_losses.append(avg_val_loss)
        
        
        current_lr = optimizer.lr.numpy()
        learning_rates.append(current_lr)
        
        
        
        print(f"Epoch [{epoch + 1}/{num_epochs}]")
        print(f"Learning rate: {current_lr:.2e}")
        print(f"Train Losses - Regression: {train_regression_losses[-1]:.4f}, Classification: {train_classification_losses[-1]:.4f}, Combined: {train_combined_losses[-1]:.4f}")
        print(f"Validation Losses - Regression: {val_regression_losses[-1]:.4f}, Classification: {val_classification_losses[-1]:.4f}, Combined: {val_combined_losses[-1]:.4f}")
        print("-------------")
        
        
        scheduler.on_epoch_end(epoch, {"val_loss": avg_val_loss})

        

        # Check for early stopping based on the new criterion
        if avg_val_loss < (1 - early_stopping_threshold) * best_val_loss:  # 0.001 corresponds to 0.1%
            epochs_without_improvement = 0
            best_val_loss = min(best_val_loss, avg_val_loss)
        else:
            epochs_without_improvement += 1

        if epochs_without_improvement >= patience:
            print(f"Early stopping triggered after {epoch + 1} epochs!")
            break
        
    train_regression_losses_all.append(train_regression_losses)
    train_classification_losses_all.append(train_classification_losses)
    train_combined_losses_all.append(train_combined_losses)
    val_regression_losses_all.append(val_regression_losses)
    val_classification_losses_all.append(val_classification_losses)
    val_combined_losses_all.append(val_combined_losses)
    
    del model
    del optimizer
    del scheduler
    del train_dataset
    del val_dataset
    del test_dataset
    del train_data
    del val_data
    del test_data
    del train_val_data
# Out:
# Epoch [1/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.1081, Classification: 0.1282, Combined: 0.6685
# Validation Losses - Regression: 0.0584, Classification: 0.0825, Combined: 0.3743
# -------------
# Epoch [2/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0399, Classification: 0.0807, Combined: 0.2800
# Validation Losses - Regression: 0.0396, Classification: 0.0756, Combined: 0.2735
# -------------
# Epoch [3/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0305, Classification: 0.0767, Combined: 0.2290
# Validation Losses - Regression: 0.0301, Classification: 0.0725, Combined: 0.2228
# -------------
# Epoch [4/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0256, Classification: 0.0753, Combined: 0.2033
# Validation Losses - Regression: 0.0229, Classification: 0.0713, Combined: 0.1856
# -------------
# Epoch [5/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0234, Classification: 0.0734, Combined: 0.1903
# Validation Losses - Regression: 0.0204, Classification: 0.0689, Combined: 0.1708
# -------------
# Epoch [6/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0234, Classification: 0.0716, Combined: 0.1886
# Validation Losses - Regression: 0.0246, Classification: 0.0679, Combined: 0.1910
# -------------
# Epoch [7/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0212, Classification: 0.0708, Combined: 0.1770
# Validation Losses - Regression: 0.0215, Classification: 0.0689, Combined: 0.1765
# -------------
# Epoch [8/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0199, Classification: 0.0703, Combined: 0.1697
# Validation Losses - Regression: 0.0257, Classification: 0.0669, Combined: 0.1955
# -------------
# Epoch [9/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0202, Classification: 0.0701, Combined: 0.1711
# Validation Losses - Regression: 0.0193, Classification: 0.0663, Combined: 0.1626
# -------------
# Epoch [10/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0201, Classification: 0.0696, Combined: 0.1701
# Validation Losses - Regression: 0.0184, Classification: 0.0658, Combined: 0.1579
# -------------
# Epoch [11/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0187, Classification: 0.0691, Combined: 0.1624
# Validation Losses - Regression: 0.0161, Classification: 0.0672, Combined: 0.1479
# -------------
# Epoch [12/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0190, Classification: 0.0686, Combined: 0.1638
# Validation Losses - Regression: 0.0165, Classification: 0.0652, Combined: 0.1479
# -------------
# Epoch [13/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0177, Classification: 0.0679, Combined: 0.1563
# Validation Losses - Regression: 0.0181, Classification: 0.0671, Combined: 0.1576
# -------------
# Epoch [14/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0174, Classification: 0.0676, Combined: 0.1548
# Validation Losses - Regression: 0.0184, Classification: 0.0649, Combined: 0.1569
# -------------
# Epoch [15/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0175, Classification: 0.0674, Combined: 0.1547
# Validation Losses - Regression: 0.0170, Classification: 0.0655, Combined: 0.1507
# -------------
# Epoch [16/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0170, Classification: 0.0668, Combined: 0.1519
# Validation Losses - Regression: 0.0198, Classification: 0.0644, Combined: 0.1634
# -------------
# Epoch [17/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0171, Classification: 0.0670, Combined: 0.1525
# Validation Losses - Regression: 0.0167, Classification: 0.0671, Combined: 0.1505
# -------------
# Epoch [18/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0165, Classification: 0.0669, Combined: 0.1492
# Validation Losses - Regression: 0.0183, Classification: 0.0650, Combined: 0.1567
# -------------
# Epoch [19/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0175, Classification: 0.0666, Combined: 0.1541
# Validation Losses - Regression: 0.0182, Classification: 0.0656, Combined: 0.1564
# -------------
# Decreasing learning rate to 0.004999999888241291
# Epoch [20/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0138, Classification: 0.0652, Combined: 0.1340
# Validation Losses - Regression: 0.0143, Classification: 0.0646, Combined: 0.1358
# -------------
# Epoch [21/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0140, Classification: 0.0653, Combined: 0.1351
# Validation Losses - Regression: 0.0138, Classification: 0.0636, Combined: 0.1328
# -------------
# Epoch [22/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0139, Classification: 0.0650, Combined: 0.1347
# Validation Losses - Regression: 0.0139, Classification: 0.0632, Combined: 0.1326
# -------------
# Epoch [23/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0139, Classification: 0.0651, Combined: 0.1348
# Validation Losses - Regression: 0.0143, Classification: 0.0652, Combined: 0.1369
# -------------
# Epoch [24/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0140, Classification: 0.0650, Combined: 0.1350
# Validation Losses - Regression: 0.0135, Classification: 0.0637, Combined: 0.1313
# -------------
# Epoch [25/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0140, Classification: 0.0650, Combined: 0.1349
# Validation Losses - Regression: 0.0153, Classification: 0.0629, Combined: 0.1393
# -------------
# Epoch [26/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0139, Classification: 0.0647, Combined: 0.1342
# Validation Losses - Regression: 0.0142, Classification: 0.0622, Combined: 0.1334
# -------------
# Epoch [27/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0139, Classification: 0.0646, Combined: 0.1339
# Validation Losses - Regression: 0.0134, Classification: 0.0631, Combined: 0.1299
# -------------
# Epoch [28/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0139, Classification: 0.0645, Combined: 0.1341
# Validation Losses - Regression: 0.0141, Classification: 0.0625, Combined: 0.1328
# -------------
# Epoch [29/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0135, Classification: 0.0646, Combined: 0.1323
# Validation Losses - Regression: 0.0141, Classification: 0.0622, Combined: 0.1327
# -------------
# Epoch [30/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0137, Classification: 0.0642, Combined: 0.1327
# Validation Losses - Regression: 0.0147, Classification: 0.0634, Combined: 0.1371
# -------------
# Decreasing learning rate to 0.0024999999441206455
# Epoch [31/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0128, Classification: 0.0634, Combined: 0.1276
# Validation Losses - Regression: 0.0130, Classification: 0.0617, Combined: 0.1266
# -------------
# Decreasing learning rate to 0.0012499999720603228
# Epoch [32/300]
# Learning rate: 1.25e-03
# Train Losses - Regression: 0.0125, Classification: 0.0629, Combined: 0.1256
# Validation Losses - Regression: 0.0127, Classification: 0.0617, Combined: 0.1255
# -------------
# Decreasing learning rate to 0.0006249999860301614
# Epoch [33/300]
# Learning rate: 6.25e-04
# Train Losses - Regression: 0.0124, Classification: 0.0625, Combined: 0.1246
# Validation Losses - Regression: 0.0126, Classification: 0.0616, Combined: 0.1245
# -------------
# Decreasing learning rate to 0.0003124999930150807
# Epoch [34/300]
# Learning rate: 3.12e-04
# Train Losses - Regression: 0.0124, Classification: 0.0624, Combined: 0.1242
# Validation Losses - Regression: 0.0125, Classification: 0.0613, Combined: 0.1235
# -------------
# Decreasing learning rate to 0.00015624999650754035
# Epoch [35/300]
# Learning rate: 1.56e-04
# Train Losses - Regression: 0.0123, Classification: 0.0623, Combined: 0.1239
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1235
# -------------
# Decreasing learning rate to 7.812499825377017e-05
# Epoch [36/300]
# Learning rate: 7.81e-05
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1238
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1234
# -------------
# Decreasing learning rate to 3.9062499126885086e-05
# Epoch [37/300]
# Learning rate: 3.91e-05
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1237
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1234
# -------------
# Decreasing learning rate to 1.9531249563442543e-05
# Epoch [38/300]
# Learning rate: 1.95e-05
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1237
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 9.765624781721272e-06
# Epoch [39/300]
# Learning rate: 9.77e-06
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1237
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 4.882812390860636e-06
# Epoch [40/300]
# Learning rate: 4.88e-06
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 2.441406195430318e-06
# Epoch [41/300]
# Learning rate: 2.44e-06
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 1.220703097715159e-06
# Epoch [42/300]
# Learning rate: 1.22e-06
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 6.103515488575795e-07
# Epoch [43/300]
# Learning rate: 6.10e-07
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 3.0517577442878974e-07
# Epoch [44/300]
# Learning rate: 3.05e-07
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 1.5258788721439487e-07
# Epoch [45/300]
# Learning rate: 1.53e-07
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 7.629394360719743e-08
# Epoch [46/300]
# Learning rate: 7.63e-08
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 3.814697180359872e-08
# Epoch [47/300]
# Learning rate: 3.81e-08
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 1.907348590179936e-08
# Epoch [48/300]
# Learning rate: 1.91e-08
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 9.53674295089968e-09
# Epoch [49/300]
# Learning rate: 9.54e-09
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 4.76837147544984e-09
# Epoch [50/300]
# Learning rate: 4.77e-09
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 2.38418573772492e-09
# Epoch [51/300]
# Learning rate: 2.38e-09
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 1.19209286886246e-09
# Epoch [52/300]
# Learning rate: 1.19e-09
# Train Losses - Regression: 0.0123, Classification: 0.0622, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0613, Combined: 0.1233
# -------------
# Decreasing learning rate to 5.9604643443123e-10
# Early stopping triggered after 52 epochs!
# Epoch [1/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0898, Classification: 0.1271, Combined: 0.5760
# Validation Losses - Regression: 0.0378, Classification: 0.0802, Combined: 0.2692
# -------------
# Epoch [2/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0324, Classification: 0.0802, Combined: 0.2421
# Validation Losses - Regression: 0.0298, Classification: 0.0743, Combined: 0.2234
# -------------
# Epoch [3/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0275, Classification: 0.0758, Combined: 0.2133
# Validation Losses - Regression: 0.0235, Classification: 0.0717, Combined: 0.1894
# -------------
# Epoch [4/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0248, Classification: 0.0741, Combined: 0.1978
# Validation Losses - Regression: 0.0254, Classification: 0.0704, Combined: 0.1972
# -------------
# Epoch [5/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0229, Classification: 0.0734, Combined: 0.1878
# Validation Losses - Regression: 0.0246, Classification: 0.0710, Combined: 0.1940
# -------------
# Epoch [6/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0225, Classification: 0.0728, Combined: 0.1851
# Validation Losses - Regression: 0.0202, Classification: 0.0705, Combined: 0.1713
# -------------
# Epoch [7/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0208, Classification: 0.0719, Combined: 0.1756
# Validation Losses - Regression: 0.0224, Classification: 0.0707, Combined: 0.1828
# -------------
# Epoch [8/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0194, Classification: 0.0713, Combined: 0.1684
# Validation Losses - Regression: 0.0220, Classification: 0.0690, Combined: 0.1792
# -------------
# Epoch [9/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0191, Classification: 0.0705, Combined: 0.1659
# Validation Losses - Regression: 0.0202, Classification: 0.0683, Combined: 0.1691
# -------------
# Epoch [10/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0189, Classification: 0.0696, Combined: 0.1639
# Validation Losses - Regression: 0.0197, Classification: 0.0679, Combined: 0.1662
# -------------
# Epoch [11/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0186, Classification: 0.0688, Combined: 0.1618
# Validation Losses - Regression: 0.0182, Classification: 0.0675, Combined: 0.1587
# -------------
# Epoch [12/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0177, Classification: 0.0678, Combined: 0.1562
# Validation Losses - Regression: 0.0169, Classification: 0.0652, Combined: 0.1500
# -------------
# Epoch [13/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0178, Classification: 0.0674, Combined: 0.1565
# Validation Losses - Regression: 0.0177, Classification: 0.0658, Combined: 0.1541
# -------------
# Epoch [14/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0170, Classification: 0.0670, Combined: 0.1521
# Validation Losses - Regression: 0.0172, Classification: 0.0669, Combined: 0.1526
# -------------
# Epoch [15/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0167, Classification: 0.0668, Combined: 0.1504
# Validation Losses - Regression: 0.0157, Classification: 0.0642, Combined: 0.1425
# -------------
# Epoch [16/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0161, Classification: 0.0667, Combined: 0.1471
# Validation Losses - Regression: 0.0157, Classification: 0.0654, Combined: 0.1441
# -------------
# Epoch [17/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0166, Classification: 0.0669, Combined: 0.1496
# Validation Losses - Regression: 0.0153, Classification: 0.0653, Combined: 0.1418
# -------------
# Epoch [18/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0162, Classification: 0.0662, Combined: 0.1470
# Validation Losses - Regression: 0.0144, Classification: 0.0636, Combined: 0.1355
# -------------
# Epoch [19/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0159, Classification: 0.0662, Combined: 0.1458
# Validation Losses - Regression: 0.0177, Classification: 0.0642, Combined: 0.1526
# -------------
# Epoch [20/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0155, Classification: 0.0659, Combined: 0.1435
# Validation Losses - Regression: 0.0148, Classification: 0.0665, Combined: 0.1406
# -------------
# Epoch [21/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0158, Classification: 0.0659, Combined: 0.1447
# Validation Losses - Regression: 0.0169, Classification: 0.0635, Combined: 0.1481
# -------------
# Epoch [22/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0153, Classification: 0.0658, Combined: 0.1425
# Validation Losses - Regression: 0.0177, Classification: 0.0634, Combined: 0.1519
# -------------
# Decreasing learning rate to 0.004999999888241291
# Epoch [23/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0135, Classification: 0.0647, Combined: 0.1320
# Validation Losses - Regression: 0.0133, Classification: 0.0625, Combined: 0.1288
# -------------
# Epoch [24/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0133, Classification: 0.0646, Combined: 0.1312
# Validation Losses - Regression: 0.0141, Classification: 0.0643, Combined: 0.1348
# -------------
# Epoch [25/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0135, Classification: 0.0647, Combined: 0.1324
# Validation Losses - Regression: 0.0132, Classification: 0.0625, Combined: 0.1284
# -------------
# Epoch [26/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0135, Classification: 0.0645, Combined: 0.1321
# Validation Losses - Regression: 0.0135, Classification: 0.0625, Combined: 0.1301
# -------------
# Epoch [27/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0134, Classification: 0.0646, Combined: 0.1316
# Validation Losses - Regression: 0.0129, Classification: 0.0631, Combined: 0.1275
# -------------
# Epoch [28/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0134, Classification: 0.0646, Combined: 0.1318
# Validation Losses - Regression: 0.0134, Classification: 0.0619, Combined: 0.1291
# -------------
# Epoch [29/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0136, Classification: 0.0643, Combined: 0.1324
# Validation Losses - Regression: 0.0150, Classification: 0.0634, Combined: 0.1383
# -------------
# Epoch [30/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0134, Classification: 0.0644, Combined: 0.1316
# Validation Losses - Regression: 0.0138, Classification: 0.0629, Combined: 0.1319
# -------------
# Epoch [31/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0135, Classification: 0.0644, Combined: 0.1317
# Validation Losses - Regression: 0.0134, Classification: 0.0624, Combined: 0.1293
# -------------
# Epoch [32/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0135, Classification: 0.0644, Combined: 0.1322
# Validation Losses - Regression: 0.0130, Classification: 0.0624, Combined: 0.1274
# -------------
# Epoch [33/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0136, Classification: 0.0642, Combined: 0.1321
# Validation Losses - Regression: 0.0136, Classification: 0.0633, Combined: 0.1315
# -------------
# Decreasing learning rate to 0.0024999999441206455
# Epoch [34/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0125, Classification: 0.0634, Combined: 0.1261
# Validation Losses - Regression: 0.0124, Classification: 0.0621, Combined: 0.1242
# -------------
# Decreasing learning rate to 0.0012499999720603228
# Epoch [35/300]
# Learning rate: 1.25e-03
# Train Losses - Regression: 0.0123, Classification: 0.0628, Combined: 0.1243
# Validation Losses - Regression: 0.0124, Classification: 0.0617, Combined: 0.1236
# -------------
# Decreasing learning rate to 0.0006249999860301614
# Epoch [36/300]
# Learning rate: 6.25e-04
# Train Losses - Regression: 0.0122, Classification: 0.0625, Combined: 0.1233
# Validation Losses - Regression: 0.0125, Classification: 0.0617, Combined: 0.1240
# -------------
# Decreasing learning rate to 0.0003124999930150807
# Epoch [37/300]
# Learning rate: 3.12e-04
# Train Losses - Regression: 0.0121, Classification: 0.0624, Combined: 0.1230
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1225
# -------------
# Decreasing learning rate to 0.00015624999650754035
# Epoch [38/300]
# Learning rate: 1.56e-04
# Train Losses - Regression: 0.0121, Classification: 0.0623, Combined: 0.1227
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1225
# -------------
# Decreasing learning rate to 7.812499825377017e-05
# Epoch [39/300]
# Learning rate: 7.81e-05
# Train Losses - Regression: 0.0121, Classification: 0.0622, Combined: 0.1225
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1224
# -------------
# Decreasing learning rate to 3.9062499126885086e-05
# Epoch [40/300]
# Learning rate: 3.91e-05
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1224
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1224
# -------------
# Decreasing learning rate to 1.9531249563442543e-05
# Epoch [41/300]
# Learning rate: 1.95e-05
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1224
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1223
# -------------
# Decreasing learning rate to 9.765624781721272e-06
# Epoch [42/300]
# Learning rate: 9.77e-06
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1224
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1223
# -------------
# Decreasing learning rate to 4.882812390860636e-06
# Epoch [43/300]
# Learning rate: 4.88e-06
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1223
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1223
# -------------
# Decreasing learning rate to 2.441406195430318e-06
# Epoch [44/300]
# Learning rate: 2.44e-06
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1223
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1223
# -------------
# Decreasing learning rate to 1.220703097715159e-06
# Epoch [45/300]
# Learning rate: 1.22e-06
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1223
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1223
# -------------
# Decreasing learning rate to 6.103515488575795e-07
# Epoch [46/300]
# Learning rate: 6.10e-07
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1223
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1223
# -------------
# Decreasing learning rate to 3.0517577442878974e-07
# Epoch [47/300]
# Learning rate: 3.05e-07
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1223
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1223
# -------------
# Decreasing learning rate to 1.5258788721439487e-07
# Epoch [48/300]
# Learning rate: 1.53e-07
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1223
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1223
# -------------
# Decreasing learning rate to 7.629394360719743e-08
# Epoch [49/300]
# Learning rate: 7.63e-08
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1223
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1223
# -------------
# Decreasing learning rate to 3.814697180359872e-08
# Epoch [50/300]
# Learning rate: 3.81e-08
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1223
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1223
# -------------
# Decreasing learning rate to 1.907348590179936e-08
# Epoch [51/300]
# Learning rate: 1.91e-08
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1223
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1223
# -------------
# Decreasing learning rate to 9.53674295089968e-09
# Epoch [52/300]
# Learning rate: 9.54e-09
# Train Losses - Regression: 0.0120, Classification: 0.0622, Combined: 0.1223
# Validation Losses - Regression: 0.0122, Classification: 0.0615, Combined: 0.1223
# -------------
# Decreasing learning rate to 4.76837147544984e-09
# Early stopping triggered after 52 epochs!
# Epoch [1/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0977, Classification: 0.1213, Combined: 0.6099
# Validation Losses - Regression: 0.0361, Classification: 0.0813, Combined: 0.2619
# -------------
# Epoch [2/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0323, Classification: 0.0800, Combined: 0.2415
# Validation Losses - Regression: 0.0270, Classification: 0.0745, Combined: 0.2092
# -------------
# Epoch [3/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0284, Classification: 0.0760, Combined: 0.2181
# Validation Losses - Regression: 0.0272, Classification: 0.0714, Combined: 0.2073
# -------------
# Epoch [4/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0251, Classification: 0.0730, Combined: 0.1987
# Validation Losses - Regression: 0.0219, Classification: 0.0702, Combined: 0.1798
# -------------
# Epoch [5/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0236, Classification: 0.0719, Combined: 0.1899
# Validation Losses - Regression: 0.0234, Classification: 0.0690, Combined: 0.1860
# -------------
# Epoch [6/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0225, Classification: 0.0708, Combined: 0.1831
# Validation Losses - Regression: 0.0214, Classification: 0.0680, Combined: 0.1749
# -------------
# Epoch [7/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0236, Classification: 0.0698, Combined: 0.1880
# Validation Losses - Regression: 0.0224, Classification: 0.0669, Combined: 0.1787
# -------------
# Epoch [8/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0209, Classification: 0.0690, Combined: 0.1734
# Validation Losses - Regression: 0.0186, Classification: 0.0663, Combined: 0.1594
# -------------
# Epoch [9/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0205, Classification: 0.0683, Combined: 0.1706
# Validation Losses - Regression: 0.0180, Classification: 0.0659, Combined: 0.1558
# -------------
# Epoch [10/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0201, Classification: 0.0676, Combined: 0.1682
# Validation Losses - Regression: 0.0165, Classification: 0.0661, Combined: 0.1488
# -------------
# Epoch [11/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0193, Classification: 0.0673, Combined: 0.1638
# Validation Losses - Regression: 0.0186, Classification: 0.0694, Combined: 0.1622
# -------------
# Epoch [12/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0189, Classification: 0.0672, Combined: 0.1616
# Validation Losses - Regression: 0.0190, Classification: 0.0645, Combined: 0.1596
# -------------
# Epoch [13/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0181, Classification: 0.0672, Combined: 0.1578
# Validation Losses - Regression: 0.0181, Classification: 0.0645, Combined: 0.1551
# -------------
# Epoch [14/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0190, Classification: 0.0665, Combined: 0.1614
# Validation Losses - Regression: 0.0187, Classification: 0.0641, Combined: 0.1577
# -------------
# Epoch [15/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0176, Classification: 0.0667, Combined: 0.1549
# Validation Losses - Regression: 0.0164, Classification: 0.0641, Combined: 0.1460
# -------------
# Epoch [16/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0177, Classification: 0.0663, Combined: 0.1551
# Validation Losses - Regression: 0.0177, Classification: 0.0635, Combined: 0.1519
# -------------
# Epoch [17/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0173, Classification: 0.0666, Combined: 0.1531
# Validation Losses - Regression: 0.0178, Classification: 0.0648, Combined: 0.1537
# -------------
# Epoch [18/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0176, Classification: 0.0661, Combined: 0.1539
# Validation Losses - Regression: 0.0186, Classification: 0.0646, Combined: 0.1576
# -------------
# Decreasing learning rate to 0.004999999888241291
# Epoch [19/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0146, Classification: 0.0647, Combined: 0.1375
# Validation Losses - Regression: 0.0142, Classification: 0.0638, Combined: 0.1348
# -------------
# Epoch [20/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0144, Classification: 0.0645, Combined: 0.1366
# Validation Losses - Regression: 0.0152, Classification: 0.0655, Combined: 0.1416
# -------------
# Epoch [21/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0145, Classification: 0.0647, Combined: 0.1374
# Validation Losses - Regression: 0.0143, Classification: 0.0631, Combined: 0.1345
# -------------
# Epoch [22/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0147, Classification: 0.0646, Combined: 0.1383
# Validation Losses - Regression: 0.0162, Classification: 0.0635, Combined: 0.1444
# -------------
# Epoch [23/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0145, Classification: 0.0645, Combined: 0.1369
# Validation Losses - Regression: 0.0143, Classification: 0.0635, Combined: 0.1351
# -------------
# Epoch [24/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0144, Classification: 0.0643, Combined: 0.1363
# Validation Losses - Regression: 0.0143, Classification: 0.0636, Combined: 0.1350
# -------------
# Epoch [25/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0145, Classification: 0.0641, Combined: 0.1365
# Validation Losses - Regression: 0.0149, Classification: 0.0634, Combined: 0.1378
# -------------
# Epoch [26/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0144, Classification: 0.0643, Combined: 0.1364
# Validation Losses - Regression: 0.0134, Classification: 0.0639, Combined: 0.1310
# -------------
# Epoch [27/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0143, Classification: 0.0640, Combined: 0.1354
# Validation Losses - Regression: 0.0138, Classification: 0.0628, Combined: 0.1320
# -------------
# Epoch [28/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0141, Classification: 0.0642, Combined: 0.1348
# Validation Losses - Regression: 0.0151, Classification: 0.0632, Combined: 0.1388
# -------------
# Epoch [29/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0141, Classification: 0.0640, Combined: 0.1345
# Validation Losses - Regression: 0.0143, Classification: 0.0624, Combined: 0.1339
# -------------
# Decreasing learning rate to 0.0024999999441206455
# Epoch [30/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0130, Classification: 0.0632, Combined: 0.1281
# Validation Losses - Regression: 0.0130, Classification: 0.0620, Combined: 0.1269
# -------------
# Decreasing learning rate to 0.0012499999720603228
# Epoch [31/300]
# Learning rate: 1.25e-03
# Train Losses - Regression: 0.0127, Classification: 0.0626, Combined: 0.1260
# Validation Losses - Regression: 0.0128, Classification: 0.0617, Combined: 0.1256
# -------------
# Decreasing learning rate to 0.0006249999860301614
# Epoch [32/300]
# Learning rate: 6.25e-04
# Train Losses - Regression: 0.0126, Classification: 0.0623, Combined: 0.1251
# Validation Losses - Regression: 0.0126, Classification: 0.0616, Combined: 0.1246
# -------------
# Decreasing learning rate to 0.0003124999930150807
# Epoch [33/300]
# Learning rate: 3.12e-04
# Train Losses - Regression: 0.0125, Classification: 0.0622, Combined: 0.1246
# Validation Losses - Regression: 0.0126, Classification: 0.0616, Combined: 0.1246
# -------------
# Decreasing learning rate to 0.00015624999650754035
# Epoch [34/300]
# Learning rate: 1.56e-04
# Train Losses - Regression: 0.0125, Classification: 0.0621, Combined: 0.1244
# Validation Losses - Regression: 0.0126, Classification: 0.0616, Combined: 0.1244
# -------------
# Decreasing learning rate to 7.812499825377017e-05
# Epoch [35/300]
# Learning rate: 7.81e-05
# Train Losses - Regression: 0.0124, Classification: 0.0620, Combined: 0.1242
# Validation Losses - Regression: 0.0126, Classification: 0.0615, Combined: 0.1244
# -------------
# Decreasing learning rate to 3.9062499126885086e-05
# Epoch [36/300]
# Learning rate: 3.91e-05
# Train Losses - Regression: 0.0124, Classification: 0.0620, Combined: 0.1241
# Validation Losses - Regression: 0.0126, Classification: 0.0616, Combined: 0.1244
# -------------
# Decreasing learning rate to 1.9531249563442543e-05
# Epoch [37/300]
# Learning rate: 1.95e-05
# Train Losses - Regression: 0.0124, Classification: 0.0620, Combined: 0.1241
# Validation Losses - Regression: 0.0126, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 9.765624781721272e-06
# Epoch [38/300]
# Learning rate: 9.77e-06
# Train Losses - Regression: 0.0124, Classification: 0.0620, Combined: 0.1241
# Validation Losses - Regression: 0.0126, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 4.882812390860636e-06
# Epoch [39/300]
# Learning rate: 4.88e-06
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1241
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 2.441406195430318e-06
# Epoch [40/300]
# Learning rate: 2.44e-06
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 1.220703097715159e-06
# Epoch [41/300]
# Learning rate: 1.22e-06
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 6.103515488575795e-07
# Epoch [42/300]
# Learning rate: 6.10e-07
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 3.0517577442878974e-07
# Epoch [43/300]
# Learning rate: 3.05e-07
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 1.5258788721439487e-07
# Epoch [44/300]
# Learning rate: 1.53e-07
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 7.629394360719743e-08
# Epoch [45/300]
# Learning rate: 7.63e-08
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 3.814697180359872e-08
# Epoch [46/300]
# Learning rate: 3.81e-08
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 1.907348590179936e-08
# Epoch [47/300]
# Learning rate: 1.91e-08
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 9.53674295089968e-09
# Epoch [48/300]
# Learning rate: 9.54e-09
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 4.76837147544984e-09
# Epoch [49/300]
# Learning rate: 4.77e-09
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 2.38418573772492e-09
# Epoch [50/300]
# Learning rate: 2.38e-09
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 1.19209286886246e-09
# Epoch [51/300]
# Learning rate: 1.19e-09
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 5.9604643443123e-10
# Epoch [52/300]
# Learning rate: 5.96e-10
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 2.98023217215615e-10
# Epoch [53/300]
# Learning rate: 2.98e-10
# Train Losses - Regression: 0.0124, Classification: 0.0619, Combined: 0.1240
# Validation Losses - Regression: 0.0125, Classification: 0.0615, Combined: 0.1243
# -------------
# Decreasing learning rate to 1.490116086078075e-10
# Early stopping triggered after 53 epochs!
# Epoch [1/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.1232, Classification: 0.1741, Combined: 0.7902
# Validation Losses - Regression: 0.0808, Classification: 0.0803, Combined: 0.4841
# -------------
# Epoch [2/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0443, Classification: 0.0808, Combined: 0.3024
# Validation Losses - Regression: 0.0331, Classification: 0.0741, Combined: 0.2397
# -------------
# Epoch [3/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0295, Classification: 0.0755, Combined: 0.2231
# Validation Losses - Regression: 0.0289, Classification: 0.0711, Combined: 0.2155
# -------------
# Epoch [4/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0250, Classification: 0.0734, Combined: 0.1985
# Validation Losses - Regression: 0.0215, Classification: 0.0700, Combined: 0.1773
# -------------
# Epoch [5/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0233, Classification: 0.0724, Combined: 0.1888
# Validation Losses - Regression: 0.0238, Classification: 0.0694, Combined: 0.1884
# -------------
# Epoch [6/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0216, Classification: 0.0716, Combined: 0.1798
# Validation Losses - Regression: 0.0208, Classification: 0.0692, Combined: 0.1733
# -------------
# Epoch [7/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0208, Classification: 0.0705, Combined: 0.1746
# Validation Losses - Regression: 0.0183, Classification: 0.0679, Combined: 0.1594
# -------------
# Epoch [8/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0195, Classification: 0.0700, Combined: 0.1674
# Validation Losses - Regression: 0.0207, Classification: 0.0665, Combined: 0.1699
# -------------
# Epoch [9/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0194, Classification: 0.0691, Combined: 0.1661
# Validation Losses - Regression: 0.0188, Classification: 0.0661, Combined: 0.1600
# -------------
# Epoch [10/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0193, Classification: 0.0682, Combined: 0.1647
# Validation Losses - Regression: 0.0182, Classification: 0.0660, Combined: 0.1571
# -------------
# Epoch [11/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0187, Classification: 0.0675, Combined: 0.1611
# Validation Losses - Regression: 0.0200, Classification: 0.0657, Combined: 0.1655
# -------------
# Epoch [12/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0185, Classification: 0.0672, Combined: 0.1597
# Validation Losses - Regression: 0.0171, Classification: 0.0663, Combined: 0.1519
# -------------
# Epoch [13/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0175, Classification: 0.0670, Combined: 0.1547
# Validation Losses - Regression: 0.0190, Classification: 0.0649, Combined: 0.1597
# -------------
# Epoch [14/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0176, Classification: 0.0668, Combined: 0.1548
# Validation Losses - Regression: 0.0196, Classification: 0.0643, Combined: 0.1624
# -------------
# Epoch [15/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0173, Classification: 0.0665, Combined: 0.1530
# Validation Losses - Regression: 0.0176, Classification: 0.0643, Combined: 0.1522
# -------------
# Epoch [16/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0169, Classification: 0.0664, Combined: 0.1508
# Validation Losses - Regression: 0.0200, Classification: 0.0641, Combined: 0.1641
# -------------
# Epoch [17/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0169, Classification: 0.0664, Combined: 0.1509
# Validation Losses - Regression: 0.0163, Classification: 0.0636, Combined: 0.1453
# -------------
# Decreasing learning rate to 0.004999999888241291
# Epoch [18/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0145, Classification: 0.0650, Combined: 0.1376
# Validation Losses - Regression: 0.0145, Classification: 0.0634, Combined: 0.1358
# -------------
# Epoch [19/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0144, Classification: 0.0653, Combined: 0.1375
# Validation Losses - Regression: 0.0149, Classification: 0.0638, Combined: 0.1381
# -------------
# Epoch [20/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0146, Classification: 0.0650, Combined: 0.1380
# Validation Losses - Regression: 0.0142, Classification: 0.0635, Combined: 0.1346
# -------------
# Epoch [21/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0145, Classification: 0.0650, Combined: 0.1377
# Validation Losses - Regression: 0.0138, Classification: 0.0632, Combined: 0.1321
# -------------
# Epoch [22/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0145, Classification: 0.0648, Combined: 0.1374
# Validation Losses - Regression: 0.0141, Classification: 0.0630, Combined: 0.1337
# -------------
# Epoch [23/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0145, Classification: 0.0650, Combined: 0.1374
# Validation Losses - Regression: 0.0142, Classification: 0.0638, Combined: 0.1347
# -------------
# Epoch [24/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0141, Classification: 0.0648, Combined: 0.1354
# Validation Losses - Regression: 0.0141, Classification: 0.0636, Combined: 0.1343
# -------------
# Epoch [25/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0142, Classification: 0.0647, Combined: 0.1357
# Validation Losses - Regression: 0.0148, Classification: 0.0633, Combined: 0.1374
# -------------
# Epoch [26/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0143, Classification: 0.0646, Combined: 0.1363
# Validation Losses - Regression: 0.0147, Classification: 0.0645, Combined: 0.1382
# -------------
# Epoch [27/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0140, Classification: 0.0646, Combined: 0.1347
# Validation Losses - Regression: 0.0138, Classification: 0.0628, Combined: 0.1320
# -------------
# Epoch [28/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0141, Classification: 0.0646, Combined: 0.1351
# Validation Losses - Regression: 0.0136, Classification: 0.0632, Combined: 0.1311
# -------------
# Decreasing learning rate to 0.0024999999441206455
# Epoch [29/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0132, Classification: 0.0638, Combined: 0.1296
# Validation Losses - Regression: 0.0131, Classification: 0.0624, Combined: 0.1279
# -------------
# Decreasing learning rate to 0.0012499999720603228
# Epoch [30/300]
# Learning rate: 1.25e-03
# Train Losses - Regression: 0.0129, Classification: 0.0634, Combined: 0.1279
# Validation Losses - Regression: 0.0129, Classification: 0.0625, Combined: 0.1271
# -------------
# Decreasing learning rate to 0.0006249999860301614
# Epoch [31/300]
# Learning rate: 6.25e-04
# Train Losses - Regression: 0.0128, Classification: 0.0631, Combined: 0.1270
# Validation Losses - Regression: 0.0128, Classification: 0.0623, Combined: 0.1263
# -------------
# Decreasing learning rate to 0.0003124999930150807
# Epoch [32/300]
# Learning rate: 3.12e-04
# Train Losses - Regression: 0.0127, Classification: 0.0629, Combined: 0.1265
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1256
# -------------
# Decreasing learning rate to 0.00015624999650754035
# Epoch [33/300]
# Learning rate: 1.56e-04
# Train Losses - Regression: 0.0127, Classification: 0.0628, Combined: 0.1263
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1256
# -------------
# Decreasing learning rate to 7.812499825377017e-05
# Epoch [34/300]
# Learning rate: 7.81e-05
# Train Losses - Regression: 0.0127, Classification: 0.0628, Combined: 0.1261
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 3.9062499126885086e-05
# Epoch [35/300]
# Learning rate: 3.91e-05
# Train Losses - Regression: 0.0127, Classification: 0.0627, Combined: 0.1260
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 1.9531249563442543e-05
# Epoch [36/300]
# Learning rate: 1.95e-05
# Train Losses - Regression: 0.0127, Classification: 0.0627, Combined: 0.1260
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 9.765624781721272e-06
# Epoch [37/300]
# Learning rate: 9.77e-06
# Train Losses - Regression: 0.0127, Classification: 0.0627, Combined: 0.1260
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 4.882812390860636e-06
# Epoch [38/300]
# Learning rate: 4.88e-06
# Train Losses - Regression: 0.0126, Classification: 0.0627, Combined: 0.1259
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 2.441406195430318e-06
# Epoch [39/300]
# Learning rate: 2.44e-06
# Train Losses - Regression: 0.0126, Classification: 0.0627, Combined: 0.1259
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 1.220703097715159e-06
# Epoch [40/300]
# Learning rate: 1.22e-06
# Train Losses - Regression: 0.0126, Classification: 0.0627, Combined: 0.1259
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 6.103515488575795e-07
# Epoch [41/300]
# Learning rate: 6.10e-07
# Train Losses - Regression: 0.0126, Classification: 0.0627, Combined: 0.1259
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 3.0517577442878974e-07
# Epoch [42/300]
# Learning rate: 3.05e-07
# Train Losses - Regression: 0.0126, Classification: 0.0627, Combined: 0.1259
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 1.5258788721439487e-07
# Epoch [43/300]
# Learning rate: 1.53e-07
# Train Losses - Regression: 0.0126, Classification: 0.0627, Combined: 0.1259
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 7.629394360719743e-08
# Epoch [44/300]
# Learning rate: 7.63e-08
# Train Losses - Regression: 0.0126, Classification: 0.0627, Combined: 0.1259
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 3.814697180359872e-08
# Epoch [45/300]
# Learning rate: 3.81e-08
# Train Losses - Regression: 0.0126, Classification: 0.0627, Combined: 0.1259
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 1.907348590179936e-08
# Epoch [46/300]
# Learning rate: 1.91e-08
# Train Losses - Regression: 0.0126, Classification: 0.0627, Combined: 0.1259
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 9.53674295089968e-09
# Epoch [47/300]
# Learning rate: 9.54e-09
# Train Losses - Regression: 0.0126, Classification: 0.0627, Combined: 0.1259
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 4.76837147544984e-09
# Epoch [48/300]
# Learning rate: 4.77e-09
# Train Losses - Regression: 0.0126, Classification: 0.0627, Combined: 0.1259
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# Decreasing learning rate to 2.38418573772492e-09
# Epoch [49/300]
# Learning rate: 2.38e-09
# Train Losses - Regression: 0.0126, Classification: 0.0627, Combined: 0.1259
# Validation Losses - Regression: 0.0127, Classification: 0.0619, Combined: 0.1254
# -------------
# ...
# Validation Losses - Regression: 0.0186, Classification: 0.0692, Combined: 0.1621
# -------------
# Epoch [9/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0189, Classification: 0.0693, Combined: 0.1636
# Validation Losses - Regression: 0.0178, Classification: 0.0655, Combined: 0.1544
# -------------
# Epoch [10/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0182, Classification: 0.0687, Combined: 0.1598
# Validation Losses - Regression: 0.0173, Classification: 0.0663, Combined: 0.1529
# -------------
# Epoch [11/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0179, Classification: 0.0680, Combined: 0.1576
# Validation Losses - Regression: 0.0170, Classification: 0.0654, Combined: 0.1504
# -------------
# Epoch [12/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0178, Classification: 0.0678, Combined: 0.1569
# Validation Losses - Regression: 0.0160, Classification: 0.0652, Combined: 0.1450
# -------------
# Epoch [13/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0179, Classification: 0.0675, Combined: 0.1568
# Validation Losses - Regression: 0.0164, Classification: 0.0653, Combined: 0.1475
# -------------
# Epoch [14/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0172, Classification: 0.0670, Combined: 0.1531
# Validation Losses - Regression: 0.0160, Classification: 0.0639, Combined: 0.1440
# -------------
# Epoch [15/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0169, Classification: 0.0666, Combined: 0.1510
# Validation Losses - Regression: 0.0164, Classification: 0.0637, Combined: 0.1459
# -------------
# Epoch [16/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0168, Classification: 0.0665, Combined: 0.1503
# Validation Losses - Regression: 0.0186, Classification: 0.0635, Combined: 0.1565
# -------------
# Epoch [17/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0166, Classification: 0.0664, Combined: 0.1495
# Validation Losses - Regression: 0.0154, Classification: 0.0643, Combined: 0.1415
# -------------
# Epoch [18/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0159, Classification: 0.0660, Combined: 0.1456
# Validation Losses - Regression: 0.0161, Classification: 0.0641, Combined: 0.1445
# -------------
# Epoch [19/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0165, Classification: 0.0660, Combined: 0.1486
# Validation Losses - Regression: 0.0152, Classification: 0.0633, Combined: 0.1395
# -------------
# Epoch [20/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0159, Classification: 0.0657, Combined: 0.1452
# Validation Losses - Regression: 0.0145, Classification: 0.0636, Combined: 0.1360
# -------------
# Epoch [21/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0154, Classification: 0.0655, Combined: 0.1427
# Validation Losses - Regression: 0.0141, Classification: 0.0626, Combined: 0.1330
# -------------
# Epoch [22/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0156, Classification: 0.0656, Combined: 0.1437
# Validation Losses - Regression: 0.0146, Classification: 0.0640, Combined: 0.1368
# -------------
# Decreasing learning rate to 0.004999999888241291
# Epoch [23/300]
# Learning rate: 5.00e-03
# Train Losses - Regression: 0.0136, Classification: 0.0644, Combined: 0.1323
# Validation Losses - Regression: 0.0138, Classification: 0.0631, Combined: 0.1321
# -------------
# Decreasing learning rate to 0.0024999999441206455
# Epoch [24/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0132, Classification: 0.0635, Combined: 0.1293
# Validation Losses - Regression: 0.0131, Classification: 0.0622, Combined: 0.1277
# -------------
# Epoch [25/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0131, Classification: 0.0635, Combined: 0.1291
# Validation Losses - Regression: 0.0132, Classification: 0.0617, Combined: 0.1277
# -------------
# Epoch [26/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0132, Classification: 0.0634, Combined: 0.1292
# Validation Losses - Regression: 0.0131, Classification: 0.0618, Combined: 0.1273
# -------------
# Epoch [27/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0131, Classification: 0.0633, Combined: 0.1290
# Validation Losses - Regression: 0.0132, Classification: 0.0629, Combined: 0.1287
# -------------
# Epoch [28/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0132, Classification: 0.0634, Combined: 0.1293
# Validation Losses - Regression: 0.0132, Classification: 0.0618, Combined: 0.1277
# -------------
# Epoch [29/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0131, Classification: 0.0633, Combined: 0.1288
# Validation Losses - Regression: 0.0132, Classification: 0.0627, Combined: 0.1286
# -------------
# Epoch [30/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0130, Classification: 0.0633, Combined: 0.1283
# Validation Losses - Regression: 0.0129, Classification: 0.0616, Combined: 0.1259
# -------------
# Epoch [31/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0130, Classification: 0.0632, Combined: 0.1280
# Validation Losses - Regression: 0.0128, Classification: 0.0614, Combined: 0.1253
# -------------
# Epoch [32/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0130, Classification: 0.0631, Combined: 0.1279
# Validation Losses - Regression: 0.0128, Classification: 0.0616, Combined: 0.1257
# -------------
# Epoch [33/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0129, Classification: 0.0631, Combined: 0.1275
# Validation Losses - Regression: 0.0129, Classification: 0.0624, Combined: 0.1268
# -------------
# Epoch [34/300]
# Learning rate: 2.50e-03
# Train Losses - Regression: 0.0129, Classification: 0.0630, Combined: 0.1274
# Validation Losses - Regression: 0.0129, Classification: 0.0617, Combined: 0.1261
# -------------
# Decreasing learning rate to 0.0012499999720603228
# Epoch [35/300]
# Learning rate: 1.25e-03
# Train Losses - Regression: 0.0125, Classification: 0.0626, Combined: 0.1252
# Validation Losses - Regression: 0.0126, Classification: 0.0613, Combined: 0.1240
# -------------
# Decreasing learning rate to 0.0006249999860301614
# Epoch [36/300]
# Learning rate: 6.25e-04
# Train Losses - Regression: 0.0124, Classification: 0.0622, Combined: 0.1242
# Validation Losses - Regression: 0.0125, Classification: 0.0612, Combined: 0.1235
# -------------
# Decreasing learning rate to 0.0003124999930150807
# Epoch [37/300]
# Learning rate: 3.12e-04
# Train Losses - Regression: 0.0123, Classification: 0.0620, Combined: 0.1236
# Validation Losses - Regression: 0.0124, Classification: 0.0611, Combined: 0.1232
# -------------
# Decreasing learning rate to 0.00015624999650754035
# Epoch [38/300]
# Learning rate: 1.56e-04
# Train Losses - Regression: 0.0123, Classification: 0.0619, Combined: 0.1234
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1228
# -------------
# Decreasing learning rate to 7.812499825377017e-05
# Epoch [39/300]
# Learning rate: 7.81e-05
# Train Losses - Regression: 0.0123, Classification: 0.0618, Combined: 0.1232
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1228
# -------------
# Decreasing learning rate to 3.9062499126885086e-05
# Epoch [40/300]
# Learning rate: 3.91e-05
# Train Losses - Regression: 0.0123, Classification: 0.0618, Combined: 0.1231
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1228
# -------------
# Decreasing learning rate to 1.9531249563442543e-05
# Epoch [41/300]
# Learning rate: 1.95e-05
# Train Losses - Regression: 0.0123, Classification: 0.0618, Combined: 0.1231
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1228
# -------------
# Decreasing learning rate to 9.765624781721272e-06
# Epoch [42/300]
# Learning rate: 9.77e-06
# Train Losses - Regression: 0.0123, Classification: 0.0618, Combined: 0.1231
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 4.882812390860636e-06
# Epoch [43/300]
# Learning rate: 4.88e-06
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1231
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1228
# -------------
# Decreasing learning rate to 2.441406195430318e-06
# Epoch [44/300]
# Learning rate: 2.44e-06
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 1.220703097715159e-06
# Epoch [45/300]
# Learning rate: 1.22e-06
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 6.103515488575795e-07
# Epoch [46/300]
# Learning rate: 6.10e-07
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 3.0517577442878974e-07
# Epoch [47/300]
# Learning rate: 3.05e-07
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 1.5258788721439487e-07
# Epoch [48/300]
# Learning rate: 1.53e-07
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 7.629394360719743e-08
# Epoch [49/300]
# Learning rate: 7.63e-08
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 3.814697180359872e-08
# Epoch [50/300]
# Learning rate: 3.81e-08
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 1.907348590179936e-08
# Epoch [51/300]
# Learning rate: 1.91e-08
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 9.53674295089968e-09
# Epoch [52/300]
# Learning rate: 9.54e-09
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 4.76837147544984e-09
# Epoch [53/300]
# Learning rate: 4.77e-09
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 2.38418573772492e-09
# Epoch [54/300]
# Learning rate: 2.38e-09
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 1.19209286886246e-09
# Epoch [55/300]
# Learning rate: 1.19e-09
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 5.9604643443123e-10
# Epoch [56/300]
# Learning rate: 5.96e-10
# Train Losses - Regression: 0.0123, Classification: 0.0617, Combined: 0.1230
# Validation Losses - Regression: 0.0124, Classification: 0.0610, Combined: 0.1227
# -------------
# Decreasing learning rate to 2.98023217215615e-10
# Early stopping triggered after 56 epochs!
# Epoch [1/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0937, Classification: 0.1370, Combined: 0.6052
# Validation Losses - Regression: 0.0470, Classification: 0.0804, Combined: 0.3155
# -------------
# Epoch [2/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0318, Classification: 0.0806, Combined: 0.2395
# Validation Losses - Regression: 0.0271, Classification: 0.0760, Combined: 0.2117
# -------------
# Epoch [3/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0263, Classification: 0.0756, Combined: 0.2074
# Validation Losses - Regression: 0.0256, Classification: 0.0717, Combined: 0.1994
# -------------
# Epoch [4/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0232, Classification: 0.0737, Combined: 0.1896
# Validation Losses - Regression: 0.0222, Classification: 0.0704, Combined: 0.1816
# -------------
# Epoch [5/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0216, Classification: 0.0727, Combined: 0.1805
# Validation Losses - Regression: 0.0210, Classification: 0.0693, Combined: 0.1743
# -------------
# Epoch [6/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0207, Classification: 0.0708, Combined: 0.1741
# Validation Losses - Regression: 0.0185, Classification: 0.0687, Combined: 0.1609
# -------------
# Epoch [7/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0199, Classification: 0.0698, Combined: 0.1692
# Validation Losses - Regression: 0.0169, Classification: 0.0675, Combined: 0.1521
# -------------
# Epoch [8/300]
# Learning rate: 1.00e-02
# Train Losses - Regression: 0.0190, Classification: 0.0691, Combined: 0.1642
# Validation Losses - Regression: 0.0194, Classification: 0.0726, Combined: 0.1699
# -------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/nilai/CMSSW_13_1_0_pre4/src/_RECO_STUDIES/nn_reco/nn.ipynb Cell 43 line 1
#      <a href='vscode-notebook-cell://ssh-remote%2Bscouting/home/nilai/CMSSW_13_1_0_pre4/src/_RECO_STUDIES/nn_reco/nn.ipynb#X53sdnNjb2RlLXJlbW90ZQ%3D%3D?line=97'>98</a> running_regression_loss     = 0.0
#      <a href='vscode-notebook-cell://ssh-remote%2Bscouting/home/nilai/CMSSW_13_1_0_pre4/src/_RECO_STUDIES/nn_reco/nn.ipynb#X53sdnNjb2RlLXJlbW90ZQ%3D%3D?line=98'>99</a> running_classification_loss = 0.0
# --> <a href='vscode-notebook-cell://ssh-remote%2Bscouting/home/nilai/CMSSW_13_1_0_pre4/src/_RECO_STUDIES/nn_reco/nn.ipynb#X53sdnNjb2RlLXJlbW90ZQ%3D%3D?line=101'>102</a> for features, targets in train_dataset:
#     <a href='vscode-notebook-cell://ssh-remote%2Bscouting/home/nilai/CMSSW_13_1_0_pre4/src/_RECO_STUDIES/nn_reco/nn.ipynb#X53sdnNjb2RlLXJlbW90ZQ%3D%3D?line=103'>104</a>     regression_loss, classification_loss, loss = train_step(features, targets)
#     <a href='vscode-notebook-cell://ssh-remote%2Bscouting/home/nilai/CMSSW_13_1_0_pre4/src/_RECO_STUDIES/nn_reco/nn.ipynb#X53sdnNjb2RlLXJlbW90ZQ%3D%3D?line=105'>106</a>     running_loss                += loss.numpy()
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py:814, in OwnedIterator.__next__(self)
#     812 def __next__(self):
#     813   try:
# --> 814     return self._next_internal()
#     815   except errors.OutOfRangeError:
#     816     raise StopIteration
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py:777, in OwnedIterator._next_internal(self)
#     774 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     775 # to communicate that there is no more data to iterate over.
#     776 with context.execution_mode(context.SYNC):
# --> 777   ret = gen_dataset_ops.iterator_get_next(
#     778       self._iterator_resource,
#     779       output_types=self._flat_output_types,
#     780       output_shapes=self._flat_output_shapes)
#     782   try:
#     783     # Fast path for the case `self._structure` is not a nested structure.
#     784     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File ~/.conda/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3023, in iterator_get_next(iterator, output_types, output_shapes, name)
#    3021 if tld.is_eager:
#    3022   try:
# -> 3023     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3024       _ctx, "IteratorGetNext", name, iterator, "output_types", output_types,
#    3025       "output_shapes", output_shapes)
#    3026     return _result
#    3027   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# compute the mean and std of the losses for each epoch
# the lists in the lists are of different lengths, so we need to pad them with the last value
# then we can compute the mean and std

train_regression_losses_all      = [x + [x[-1]] * (max(map(len, train_regression_losses_all)) - len(x)) for x in train_regression_losses_all]
train_classification_losses_all  = [x + [x[-1]] * (max(map(len, train_classification_losses_all)) - len(x)) for x in train_classification_losses_all]
train_combined_losses_all        = [x + [x[-1]] * (max(map(len, train_combined_losses_all)) - len(x)) for x in train_combined_losses_all]

val_regression_losses_all        = [x + [x[-1]] * (max(map(len, val_regression_losses_all)) - len(x)) for x in val_regression_losses_all]
val_classification_losses_all    = [x + [x[-1]] * (max(map(len, val_classification_losses_all)) - len(x)) for x in val_classification_losses_all]
val_combined_losses_all          = [x + [x[-1]] * (max(map(len, val_combined_losses_all)) - len(x)) for x in val_combined_losses_all]

train_regression_losses_mean     = np.mean(np.array(train_regression_losses_all), axis=0)[1:]
train_regression_losses_std      = np.std(np.array(train_regression_losses_all), axis=0)[1:]
train_classification_losses_mean = np.mean(np.array(train_classification_losses_all), axis=0)[1:]
train_classification_losses_std  = np.std(np.array(train_classification_losses_all), axis=0)[1:]
train_combined_losses_mean       = np.mean(np.array(train_combined_losses_all), axis=0)[1:]
train_combined_losses_std        = np.std(np.array(train_combined_losses_all), axis=0)[1:]

val_regression_losses_mean       = np.mean(np.array(val_regression_losses_all), axis=0)[1:]
val_regression_losses_std        = np.std(np.array(val_regression_losses_all), axis=0)[1:]
val_classification_losses_mean   = np.mean(np.array(val_classification_losses_all), axis=0)[1:]
val_classification_losses_std    = np.std(np.array(val_classification_losses_all), axis=0)[1:]
val_combined_losses_mean         = np.mean(np.array(val_combined_losses_all), axis=0)[1:]
val_combined_losses_std          = np.std(np.array(val_combined_losses_all), axis=0)[1:]

# %%
# REGRESSION LOSS
fig, ax = plt.subplots(figsize=FIGSIZE, constrained_layout=True)
ax.grid(which="major", axis="both", alpha=0.3, color="gray", linestyle="-")
ax.set_axisbelow(True)
hep.cms.label(
    ax     = ax,
    data   = True,
    label  = "Preliminary",
    rlabel = "ZeroBias 2023C (13.6 TeV)",
    fontsize = 36,
)
ax.plot(train_regression_losses_mean, label="Train", color=PALETTE[0], linewidth=3)
ax.fill_between(np.arange(len(train_regression_losses_mean)), train_regression_losses_mean - train_regression_losses_std, train_regression_losses_mean + train_regression_losses_std, alpha=0.3)
ax.plot(val_regression_losses_mean, label="Validation", color=PALETTE[-1], linewidth=3)
ax.fill_between(np.arange(len(val_regression_losses_mean)), val_regression_losses_mean - val_regression_losses_std, val_regression_losses_mean + val_regression_losses_std, alpha=0.3)
ax.set_xlabel("Epoch", fontsize=36)
ax.set_ylabel("Regression Loss", fontsize=36)
ax.legend(fontsize=36)
# ax.set_yscale("log")
ax.tick_params(axis='both', which='major', labelsize=36)

if PLOT_FLAG:
    fig.savefig(f"{PLOT_PATH}regression_loss_{learning_rate}_{batch_size}_{reg_strength}_{regression_weight}_{min_loss_improvement}_{early_stopping_threshold}.pdf", dpi=300, facecolor="white")

plt.show()

# CLASSIFICATION LOSS
fig, ax = plt.subplots(figsize=FIGSIZE, constrained_layout=True)
ax.grid(which="major", axis="both", alpha=0.3, color="gray", linestyle="-")
ax.set_axisbelow(True)
hep.cms.label(
    ax     = ax,
    data   = True,
    label  = "Preliminary",
    rlabel = "ZeroBias 2023C (13.6 TeV)",
    fontsize = 36,
)
ax.plot(train_classification_losses_mean, label="Train", color=PALETTE[0], linewidth=3)
ax.fill_between(np.arange(len(train_classification_losses_mean)), train_classification_losses_mean - train_classification_losses_std, train_classification_losses_mean + train_classification_losses_std, alpha=0.3)
ax.plot(val_classification_losses_mean, label="Validation", color=PALETTE[-1], linewidth=3)
ax.fill_between(np.arange(len(val_classification_losses_mean)), val_classification_losses_mean - val_classification_losses_std, val_classification_losses_mean + val_classification_losses_std, alpha=0.3)
ax.set_xlabel("Epoch", fontsize=36)
ax.set_ylabel("Classification Loss", fontsize=36)
ax.legend(fontsize=36)
# ax.set_yscale("log")
ax.tick_params(axis='both', which='major', labelsize=36)

if PLOT_FLAG:
    fig.savefig(f"{PLOT_PATH}classification_loss_{learning_rate}_{batch_size}_{reg_strength}_{regression_weight}_{min_loss_improvement}_{early_stopping_threshold}.pdf", dpi=300, facecolor="white")

plt.show()

# COMBINED LOSS
fig, ax = plt.subplots(figsize=FIGSIZE, constrained_layout=True)
ax.grid(which="major", axis="both", alpha=0.3, color="gray", linestyle="-")
ax.set_axisbelow(True)
hep.cms.label(
    ax     = ax,
    data   = True,
    label  = "Preliminary",
    rlabel = "ZeroBias 2023C (13.6 TeV)",
    fontsize = 36,
)
ax.plot(train_combined_losses_mean, label="Train", color=PALETTE[0], linewidth=3)
ax.fill_between(np.arange(len(train_combined_losses_mean)), train_combined_losses_mean - train_combined_losses_std, train_combined_losses_mean + train_combined_losses_std, alpha=0.3)
ax.plot(val_combined_losses_mean, label="Validation", color=PALETTE[-1], linewidth=3)
ax.fill_between(np.arange(len(val_combined_losses_mean)), val_combined_losses_mean - val_combined_losses_std, val_combined_losses_mean + val_combined_losses_std, alpha=0.3)
ax.set_xlabel("Epoch", fontsize=36)
ax.set_ylabel("Combined Loss", fontsize=36)
ax.legend(fontsize=36)
# ax.set_yscale("log")
ax.tick_params(axis='both', which='major', labelsize=36)

if PLOT_FLAG:
    fig.savefig(f"{PLOT_PATH}combined_loss_{learning_rate}_{batch_size}_{reg_strength}_{regression_weight}_{min_loss_improvement}_{early_stopping_threshold}.pdf", dpi=300, facecolor="white")

plt.show()
